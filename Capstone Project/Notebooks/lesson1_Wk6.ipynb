# %% [markdown]
# Vanessa Wafa Wehbe

# %% [markdown]
# # Notebook for practical exercises | Week #6 Lesson #1
#
#
# #### Fusing Images and Metadata
#
# In this notebook, we will explore multi-modal data integration. Our goal is to improve the diagnostic accuracy of a chest X-ray classifier by combining two distinct types of data:
# 1.  Image Data: The chest X-ray images themselves.
# 2.  Tabular Data: Structured patient demographics, specifically 'Patient Age' and 'Patient Sex'.
#
# Using the [NIH ChestX-ray-14](https://nihcc.app.box.com/v/ChestXray-NIHCC) dataset with demographic categories. Demographic information can be a powerful predictor for many diseases. For example, the likelihood of certain conditions changes significantly with age. By teaching our model to consider both the visual patterns in the X-ray and the patient's metadata, we hope to build a more accurate and context-aware diagnostic tool.
#
# We will implement and compare two common fusion strategies:
# *   Concatenation-based Fusion: A simple and robust method where features from both modalities are combined and fed to a classifier.
# *   Attention-based Fusion: A more sophisticated method where the tabular data "gates" or modulates the image features, allowing the model to learn context-specific visual patterns.
# *   Bilinear Pooling Fusion: An expressive method that models pairwise feature interactions.
#
# Compare their validation AUC and metrics, and discuss which fusion strategy performs best and why.
#
# Your task is to complete the code snippets marked with `# COMPLETE`, run the training, and analyze the results.

# %% [markdown]
# ## Dataset
#
# [NIH ChestX-ray-14](https://nihcc.app.box.com/v/ChestXray-NIHCC) dataset comprises 112,120 frontal-view X-ray images of 30,805 unique patients with the text-mined fourteen disease image labels (where each image can have multi-labels), mined from the associated radiological reports using natural language processing.
# Fourteen common thoracic pathologies include Atelectasis, Consolidation, Infiltration, Pneumothorax, Edema, Emphysema, Fibrosis, Effusion, Pneumonia, Pleural_thickening, Cardiomegaly, Nodule, Mass and Hernia.
#
# It contains:
# 1. 112,120 frontal-view chest X-ray PNG images in 1024*1024 resolution (under images folder)
# 2. Meta data for all images (Data_Entry_2017.csv): Image Index, Finding Labels, Follow-up #, Patient ID, Patient Age, Patient Gender, View Position, Original Image Size and Original Image Pixel Spacing.
# 3. Bounding boxes for ~1000 images (BBox_List_2017.csv): Image Index, Finding Label, Bbox[x, y, w, h]. [x y] are coordinates of each box's topleft corner. [w h] represent the width and height of each box.
# 4. The data split from previous week
# Here, we will use a subsample of this dataset along with pretrained models from the last week.

# %% [markdown]
# ## Download

# %%
DATA_PATH = "/content"
# !curl -L https://uni-bonn.sciebo.de/s/ya8ezZDk9yR3NWB/download/test_df.csv --output {DATA_PATH}/test_df.csv
# !curl -L https://uni-bonn.sciebo.de/s/yfSiQQPJex6zaPq/download/train_df.csv --output {DATA_PATH}/train_df.csv
# !curl -L https://uni-bonn.sciebo.de/s/PpSnH6r5WGg75Mz/download/val_df.csv --output {DATA_PATH}/val_df.csv

# !curl -L https://uni-bonn.sciebo.de/s/97mg2KaEkC2id7c/download/densenet121-classification.pth --output {DATA_PATH}/densenet121-classification.pth
# !curl -L https://uni-bonn.sciebo.de/s/cTgsNw4bg6cQmqG/download/concat_model_best_auc.pth --output {DATA_PATH}/concat_model_best_auc.pth
# !curl -L https://uni-bonn.sciebo.de/s/LjM2xfxTwbtQC9k/download/attention_model_best_auc.pth --output {DATA_PATH}/attention_model_best_auc.pth
# !curl -L https://uni-bonn.sciebo.de/s/W7qd6BSQKyk9XtX/download/bilinear_model_best_auc.pth --output {DATA_PATH}/bilinear_model_best_auc.pth

# !curl -L https://uni-bonn.sciebo.de/s/J3GFK3bsHGDfwAC/download/data_cxr8.zip --output {DATA_PATH}/data.zip
# !unzip {DATA_PATH}/data.zip -d {DATA_PATH}
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/images/00020408_013.png
#   inflating: /content/images/00020408_015.png
#   inflating: /content/images/00020408_018.png
#   inflating: /content/images/00020408_023.png
#   inflating: /content/images/00020408_026.png
#   inflating: /content/images/00020408_034.png
#   inflating: /content/images/00020408_039.png
#   inflating: /content/images/00020408_041.png
#   inflating: /content/images/00020408_042.png
#   inflating: /content/images/00020408_043.png
#   inflating: /content/images/00020408_045.png
#   inflating: /content/images/00020408_048.png
#   inflating: /content/images/00020408_051.png
#   inflating: /content/images/00020408_056.png
#   inflating: /content/images/00020408_060.png
#   inflating: /content/images/00020408_061.png
#   inflating: /content/images/00020410_001.png
#   inflating: /content/images/00020410_002.png
#   inflating: /content/images/00020410_005.png
#   inflating: /content/images/00020410_006.png
#   inflating: /content/images/00020410_007.png
#   inflating: /content/images/00020415_002.png
#   inflating: /content/images/00020419_000.png
#   inflating: /content/images/00020426_002.png
#   inflating: /content/images/00020427_000.png
#   inflating: /content/images/00020427_005.png
#   inflating: /content/images/00020427_008.png
#   inflating: /content/images/00020427_010.png
#   inflating: /content/images/00020427_012.png
#   inflating: /content/images/00020429_012.png
#   inflating: /content/images/00020429_013.png
#   inflating: /content/images/00020429_014.png
#   inflating: /content/images/00020429_015.png
#   inflating: /content/images/00020429_016.png
#   inflating: /content/images/00020429_017.png
#   inflating: /content/images/00020429_018.png
#   inflating: /content/images/00020429_022.png
#   inflating: /content/images/00020429_026.png
#   inflating: /content/images/00020429_027.png
#   inflating: /content/images/00020430_001.png
#   inflating: /content/images/00020434_008.png
#   inflating: /content/images/00020434_012.png
#   inflating: /content/images/00020436_004.png
#   inflating: /content/images/00020436_000.png
#   inflating: /content/images/00020436_001.png
#   inflating: /content/images/00020436_002.png
#   inflating: /content/images/00020437_000.png
#   inflating: /content/images/00020437_008.png
#   inflating: /content/images/00020438_001.png
#   inflating: /content/images/00020438_002.png
#   inflating: /content/images/00020438_003.png
#   inflating: /content/images/00020438_010.png
#   inflating: /content/images/00020447_000.png
#   inflating: /content/images/00020450_000.png
#   inflating: /content/images/00020450_002.png
#   inflating: /content/images/00020450_003.png
#   inflating: /content/images/00020450_004.png
#   inflating: /content/images/00020450_005.png
#   inflating: /content/images/00020450_023.png
#   inflating: /content/images/00020451_000.png
#   inflating: /content/images/00020455_005.png
#   inflating: /content/images/00020455_006.png
#   inflating: /content/images/00020457_000.png
#   inflating: /content/images/00020458_018.png
#   inflating: /content/images/00020458_019.png
#   inflating: /content/images/00020458_020.png
#   inflating: /content/images/00020458_021.png
#   inflating: /content/images/00020461_000.png
#   inflating: /content/images/00020469_001.png
#   inflating: /content/images/00020469_003.png
#   inflating: /content/images/00020469_005.png
#   inflating: /content/images/00020469_004.png
#   inflating: /content/images/00020469_009.png
#   inflating: /content/images/00020469_010.png
#   inflating: /content/images/00020469_011.png
#   inflating: /content/images/00020471_001.png
#   inflating: /content/images/00020471_002.png
#   inflating: /content/images/00020472_001.png
#   inflating: /content/images/00020472_004.png
#   inflating: /content/images/00020473_001.png
#   inflating: /content/images/00020473_002.png
#   inflating: /content/images/00020474_000.png
#   inflating: /content/images/00020477_002.png
#   inflating: /content/images/00020481_004.png
#   inflating: /content/images/00020482_013.png
#   inflating: /content/images/00020482_015.png
#   inflating: /content/images/00020482_017.png
#   inflating: /content/images/00020482_016.png
#   inflating: /content/images/00020482_028.png
#   inflating: /content/images/00020482_031.png
#   inflating: /content/images/00020482_038.png
#   inflating: /content/images/00020482_039.png
#   inflating: /content/images/00020482_047.png
#   inflating: /content/images/00020482_048.png
#   inflating: /content/images/00020482_062.png
#   inflating: /content/images/00020485_000.png
#   inflating: /content/images/00020491_001.png
#   inflating: /content/images/00020492_000.png
#   inflating: /content/images/00020492_001.png
#   inflating: /content/images/00020499_010.png
#   inflating: /content/images/00020499_011.png
#   inflating: /content/images/00020501_003.png
#   inflating: /content/images/00020503_009.png
#   inflating: /content/images/00020504_000.png
#   inflating: /content/images/00020505_002.png
#   inflating: /content/images/00020505_005.png
#   inflating: /content/images/00020505_006.png
#   inflating: /content/images/00020513_003.png
#   inflating: /content/images/00020513_009.png
#   inflating: /content/images/00020513_012.png
#   inflating: /content/images/00020513_015.png
#   inflating: /content/images/00020513_016.png
#   inflating: /content/images/00020513_017.png
#   inflating: /content/images/00020513_019.png
#   inflating: /content/images/00020513_022.png
#   inflating: /content/images/00020513_031.png
#   inflating: /content/images/00020513_032.png
#   inflating: /content/images/00020513_033.png
#   inflating: /content/images/00020513_034.png
#   inflating: /content/images/00020518_000.png
#   inflating: /content/images/00020520_004.png
#   inflating: /content/images/00020529_000.png
#   inflating: /content/images/00020534_002.png
#   inflating: /content/images/00020537_003.png
#   inflating: /content/images/00020537_004.png
#   inflating: /content/images/00020537_005.png
#   inflating: /content/images/00020537_006.png
#   inflating: /content/images/00020539_000.png
#   inflating: /content/images/00020539_001.png
#   inflating: /content/images/00020539_002.png
#   inflating: /content/images/00020565_001.png
#   inflating: /content/images/00020584_000.png
#   inflating: /content/images/00020589_005.png
#   inflating: /content/images/00020601_000.png
#   inflating: /content/images/00020601_002.png
#   inflating: /content/images/00020601_003.png
#   inflating: /content/images/00020601_004.png
#   inflating: /content/images/00020607_004.png
#   inflating: /content/images/00020611_000.png
#   inflating: /content/images/00020611_001.png
#   inflating: /content/images/00020611_002.png
#   inflating: /content/images/00020617_000.png
#   inflating: /content/images/00020622_001.png
#   inflating: /content/images/00020624_001.png
#   inflating: /content/images/00020624_003.png
#   inflating: /content/images/00020624_004.png
#   inflating: /content/images/00020624_014.png
#   inflating: /content/images/00020624_006.png
#   inflating: /content/images/00020624_015.png
#   inflating: /content/images/00020629_008.png
#   inflating: /content/images/00020629_010.png
#   inflating: /content/images/00020629_012.png
#   inflating: /content/images/00020629_016.png
#   inflating: /content/images/00020629_017.png
#   inflating: /content/images/00020630_013.png
#   inflating: /content/images/00020631_000.png
#   inflating: /content/images/00020631_002.png
#   inflating: /content/images/00020631_003.png
#   inflating: /content/images/00020632_001.png
#   inflating: /content/images/00020636_000.png
#   inflating: /content/images/00020642_004.png
#   inflating: /content/images/00020644_000.png
#   inflating: /content/images/00020647_000.png
#   inflating: /content/images/00020648_003.png
#   inflating: /content/images/00020648_004.png
#   inflating: /content/images/00020648_001.png
#   inflating: /content/images/00020648_002.png
#   inflating: /content/images/00020649_000.png
#   inflating: /content/images/00020649_002.png
#   inflating: /content/images/00020652_000.png
#   inflating: /content/images/00020652_001.png
#   inflating: /content/images/00020652_005.png
#   inflating: /content/images/00020652_009.png
#   inflating: /content/images/00020652_015.png
#   inflating: /content/images/00020652_017.png
#   inflating: /content/images/00020657_000.png
#   inflating: /content/images/00020659_000.png
#   inflating: /content/images/00020664_000.png
#   inflating: /content/images/00020671_000.png
#   inflating: /content/images/00020671_004.png
#   inflating: /content/images/00020671_008.png
#   inflating: /content/images/00020671_014.png
#   inflating: /content/images/00020671_015.png
#   inflating: /content/images/00020671_016.png
#   inflating: /content/images/00020671_018.png
#   inflating: /content/images/00020673_000.png
#   inflating: /content/images/00020673_005.png
#   inflating: /content/images/00020673_011.png
#   inflating: /content/images/00020673_016.png
#   inflating: /content/images/00020673_017.png
#   inflating: /content/images/00020673_019.png
#   inflating: /content/images/00020673_021.png
#   inflating: /content/images/00020673_024.png
#   inflating: /content/images/00020673_029.png
#   inflating: /content/images/00020673_031.png
#   inflating: /content/images/00020673_036.png
#   inflating: /content/images/00020673_038.png
#   inflating: /content/images/00020673_043.png
#   inflating: /content/images/00020673_042.png
#   inflating: /content/images/00020673_045.png
#   inflating: /content/images/00020673_049.png
#   inflating: /content/images/00020673_051.png
#   inflating: /content/images/00020673_052.png
#   inflating: /content/images/00020680_001.png
#   inflating: /content/images/00020682_000.png
#   inflating: /content/images/00020690_001.png
#   inflating: /content/images/00020691_002.png
#   inflating: /content/images/00020691_003.png
#   inflating: /content/images/00020693_000.png
#   inflating: /content/images/00020697_003.png
#   inflating: /content/images/00020699_002.png
#   inflating: /content/images/00020699_006.png
#   inflating: /content/images/00020699_008.png
#   inflating: /content/images/00020702_001.png
#   inflating: /content/images/00020702_002.png
#   inflating: /content/images/00020702_004.png
#   inflating: /content/images/00020702_005.png
#   inflating: /content/images/00020702_009.png
#   inflating: /content/images/00020703_006.png
#   inflating: /content/images/00020703_015.png
#   inflating: /content/images/00020703_016.png
#   inflating: /content/images/00020703_026.png
#   inflating: /content/images/00020706_002.png
#   inflating: /content/images/00020714_000.png
#   inflating: /content/images/00020716_001.png
#   inflating: /content/images/00020721_000.png
#   inflating: /content/images/00020725_004.png
#   inflating: /content/images/00020725_012.png
#   inflating: /content/images/00020725_011.png
#   inflating: /content/images/00020725_020.png
#   inflating: /content/images/00020725_021.png
#   inflating: /content/images/00020725_027.png
#   inflating: /content/images/00020725_028.png
#   inflating: /content/images/00020725_031.png
#   inflating: /content/images/00020725_034.png
#   inflating: /content/images/00020725_035.png
#   inflating: /content/images/00020730_000.png
#   inflating: /content/images/00020735_000.png
#   inflating: /content/images/00020747_003.png
#   inflating: /content/images/00020747_005.png
#   inflating: /content/images/00020751_002.png
#   inflating: /content/images/00020751_003.png
#   inflating: /content/images/00020751_004.png
#   inflating: /content/images/00020751_006.png
#   inflating: /content/images/00020751_007.png
#   inflating: /content/images/00020755_002.png
#   inflating: /content/images/00020755_001.png
#   inflating: /content/images/00020765_000.png
#   inflating: /content/images/00020767_000.png
#   inflating: /content/images/00020767_001.png
#   inflating: /content/images/00020772_000.png
#   inflating: /content/images/00020772_002.png
#   inflating: /content/images/00020772_006.png
#   inflating: /content/images/00020772_005.png
#   inflating: /content/images/00020772_007.png
#   inflating: /content/images/00020772_010.png
#   inflating: /content/images/00020772_011.png
#   inflating: /content/images/00020772_014.png
#   inflating: /content/images/00020773_003.png
#   inflating: /content/images/00020773_005.png
#   inflating: /content/images/00020773_006.png
#   inflating: /content/images/00020773_007.png
#   inflating: /content/images/00020774_000.png
#   inflating: /content/images/00020776_002.png
#   inflating: /content/images/00020781_001.png
#   inflating: /content/images/00020781_005.png
#   inflating: /content/images/00020781_006.png
#   inflating: /content/images/00020785_001.png
#   inflating: /content/images/00020793_001.png
#   inflating: /content/images/00020793_002.png
#   inflating: /content/images/00020809_005.png
#   inflating: /content/images/00020809_009.png
#   inflating: /content/images/00020810_002.png
#   inflating: /content/images/00020810_003.png
#   inflating: /content/images/00020810_004.png
#   inflating: /content/images/00020811_017.png
#   inflating: /content/images/00020811_003.png
#   inflating: /content/images/00020812_000.png
#   inflating: /content/images/00020819_005.png
#   inflating: /content/images/00020819_007.png
#   inflating: /content/images/00020819_008.png
#   inflating: /content/images/00020819_009.png
#   inflating: /content/images/00020821_000.png
#   inflating: /content/images/00020825_000.png
#   inflating: /content/images/00020826_009.png
#   inflating: /content/images/00020826_017.png
#   inflating: /content/images/00020826_018.png
#   inflating: /content/images/00020830_002.png
#   inflating: /content/images/00020830_003.png
#   inflating: /content/images/00020843_001.png
#   inflating: /content/images/00020843_002.png
#   inflating: /content/images/00020843_003.png
#   inflating: /content/images/00020845_004.png
#   inflating: /content/images/00020848_000.png
#   inflating: /content/images/00020852_001.png
#   inflating: /content/images/00020852_002.png
#   inflating: /content/images/00020852_003.png
#   inflating: /content/images/00020852_006.png
#   inflating: /content/images/00020852_007.png
#   inflating: /content/images/00020852_008.png
#   inflating: /content/images/00020852_010.png
#   inflating: /content/images/00020852_013.png
#   inflating: /content/images/00020852_016.png
#   inflating: /content/images/00020852_018.png
#   inflating: /content/images/00020852_021.png
#   inflating: /content/images/00020855_001.png
#   inflating: /content/images/00020857_002.png
#   inflating: /content/images/00020857_009.png
#   inflating: /content/images/00020867_000.png
#   inflating: /content/images/00020869_013.png
#   inflating: /content/images/00020869_007.png
#   inflating: /content/images/00020870_002.png
#   inflating: /content/images/00020880_003.png
#   inflating: /content/images/00020880_002.png
#   inflating: /content/images/00020894_006.png
#   inflating: /content/images/00020895_001.png
#   inflating: /content/images/00020900_000.png
#   inflating: /content/images/00020911_005.png
#   inflating: /content/images/00020918_000.png
#   inflating: /content/images/00020921_001.png
#   inflating: /content/images/00020921_002.png
#   inflating: /content/images/00020922_003.png
#   inflating: /content/images/00020928_003.png
#   inflating: /content/images/00020933_002.png
#   inflating: /content/images/00020935_002.png
#   inflating: /content/images/00020935_003.png
#   inflating: /content/images/00020935_004.png
#   inflating: /content/images/00020941_000.png
#   inflating: /content/images/00020945_002.png
#   inflating: /content/images/00020945_005.png
#   inflating: /content/images/00020945_014.png
#   inflating: /content/images/00020945_017.png
#   inflating: /content/images/00020945_018.png
#   inflating: /content/images/00020945_019.png
#   inflating: /content/images/00020947_000.png
#   inflating: /content/images/00020949_003.png
#   inflating: /content/images/00020949_000.png
#   inflating: /content/images/00020949_001.png
#   inflating: /content/images/00020953_000.png
#   inflating: /content/images/00020953_001.png
#   inflating: /content/images/00020958_001.png
#   inflating: /content/images/00020960_001.png
#   inflating: /content/images/00020960_002.png
#   inflating: /content/images/00020966_000.png
#   inflating: /content/images/00020966_001.png
#   inflating: /content/images/00020966_003.png
#   inflating: /content/images/00020966_004.png
#   inflating: /content/images/00020967_001.png
#   inflating: /content/images/00020967_005.png
#   inflating: /content/images/00020967_013.png
#   inflating: /content/images/00020967_020.png
#   inflating: /content/images/00020967_021.png
#   inflating: /content/images/00020972_000.png
#   inflating: /content/images/00020974_000.png
#   inflating: /content/images/00020976_000.png
#   inflating: /content/images/00020979_004.png
#   inflating: /content/images/00020979_007.png
#   inflating: /content/images/00020983_000.png
#   inflating: /content/images/00020987_000.png
#   inflating: /content/images/00021001_000.png
#   inflating: /content/images/00021006_020.png
#   inflating: /content/images/00021006_027.png
#   inflating: /content/images/00021006_030.png
#   inflating: /content/images/00021006_003.png
#   inflating: /content/images/00021009_002.png
#   inflating: /content/images/00021011_005.png
#   inflating: /content/images/00021012_000.png
#   inflating: /content/images/00021012_001.png
#   inflating: /content/images/00021012_002.png
#   inflating: /content/images/00021012_004.png
#   inflating: /content/images/00021012_006.png
#   inflating: /content/images/00021012_005.png
#   inflating: /content/images/00021023_005.png
#   inflating: /content/images/00021023_007.png
#   inflating: /content/images/00021023_008.png
#   inflating: /content/images/00021023_014.png
#   inflating: /content/images/00021023_016.png
#   inflating: /content/images/00021023_020.png
#   inflating: /content/images/00021024_007.png
#   inflating: /content/images/00021024_008.png
#   inflating: /content/images/00021024_014.png
#   inflating: /content/images/00021024_015.png
#   inflating: /content/images/00021024_016.png
#   inflating: /content/images/00021024_017.png
#   inflating: /content/images/00021035_017.png
#   inflating: /content/images/00021035_016.png
#   inflating: /content/images/00021036_001.png
#   inflating: /content/images/00021036_002.png
#   inflating: /content/images/00021038_000.png
#   inflating: /content/images/00021039_002.png
#   inflating: /content/images/00021040_000.png
#   inflating: /content/images/00021041_001.png
#   inflating: /content/images/00021041_000.png
#   inflating: /content/images/00021041_004.png
#   inflating: /content/images/00021041_005.png
#   inflating: /content/images/00021041_008.png
#   inflating: /content/images/00021041_009.png
#   inflating: /content/images/00021041_010.png
#   inflating: /content/images/00021041_011.png
#   inflating: /content/images/00021041_012.png
#   inflating: /content/images/00021047_012.png
#   inflating: /content/images/00021047_020.png
#   inflating: /content/images/00021049_001.png
#   inflating: /content/images/00021055_000.png
#   inflating: /content/images/00021057_006.png
#   inflating: /content/images/00021065_002.png
#   inflating: /content/images/00021067_000.png
#   inflating: /content/images/00021073_003.png
#   inflating: /content/images/00021073_011.png
#   inflating: /content/images/00021073_013.png
#   inflating: /content/images/00021073_014.png
#   inflating: /content/images/00021073_016.png
#   inflating: /content/images/00021074_000.png
#   inflating: /content/images/00021083_003.png
#   inflating: /content/images/00021086_000.png
#   inflating: /content/images/00021086_001.png
#   inflating: /content/images/00021086_003.png
#   inflating: /content/images/00021086_004.png
#   inflating: /content/images/00021086_005.png
#   inflating: /content/images/00021087_002.png
#   inflating: /content/images/00021091_003.png
#   inflating: /content/images/00021091_004.png
#   inflating: /content/images/00021092_001.png
#   inflating: /content/images/00021092_002.png
#   inflating: /content/images/00021092_004.png
#   inflating: /content/images/00021092_006.png
#   inflating: /content/images/00021110_001.png
#   inflating: /content/images/00021112_001.png
#   inflating: /content/images/00021112_002.png
#   inflating: /content/images/00021114_004.png
#   inflating: /content/images/00021115_002.png
#   inflating: /content/images/00021115_001.png
#   inflating: /content/images/00021118_001.png
#   inflating: /content/images/00021118_002.png
#   inflating: /content/images/00021118_006.png
#   inflating: /content/images/00021119_006.png
#   inflating: /content/images/00021120_000.png
#   inflating: /content/images/00021127_012.png
#   inflating: /content/images/00021127_015.png
#   inflating: /content/images/00021127_017.png
#   inflating: /content/images/00021127_003.png
#   inflating: /content/images/00021127_004.png
#   inflating: /content/images/00021127_002.png
#   inflating: /content/images/00021127_010.png
#   inflating: /content/images/00021128_002.png
#   inflating: /content/images/00021130_001.png
#   inflating: /content/images/00021131_002.png
#   inflating: /content/images/00021131_003.png
#   inflating: /content/images/00021137_000.png
#   inflating: /content/images/00021141_000.png
#   inflating: /content/images/00021150_000.png
#   inflating: /content/images/00021154_005.png
#   inflating: /content/images/00021162_000.png
#   inflating: /content/images/00021162_001.png
#   inflating: /content/images/00021164_003.png
#   inflating: /content/images/00021166_000.png
#   inflating: /content/images/00021167_000.png
#   inflating: /content/images/00021171_000.png
#   inflating: /content/images/00021171_007.png
#   inflating: /content/images/00021175_000.png
#   inflating: /content/images/00021176_000.png
#   inflating: /content/images/00021177_000.png
#   inflating: /content/images/00021179_000.png
#   inflating: /content/images/00021179_002.png
#   inflating: /content/images/00021179_010.png
#   inflating: /content/images/00021180_000.png
#   inflating: /content/images/00021181_000.png
#   inflating: /content/images/00021181_002.png
#   inflating: /content/images/00021182_001.png
#   inflating: /content/images/00021182_003.png
#   inflating: /content/images/00021182_006.png
#   inflating: /content/images/00021188_003.png
#   inflating: /content/images/00021188_010.png
#   inflating: /content/images/00021188_011.png
#   inflating: /content/images/00021188_012.png
#   inflating: /content/images/00021188_001.png
#   inflating: /content/images/00021195_001.png
#   inflating: /content/images/00021197_003.png
#   inflating: /content/images/00021201_005.png
#   inflating: /content/images/00021201_008.png
#   inflating: /content/images/00021201_009.png
#   inflating: /content/images/00021201_012.png
#   inflating: /content/images/00021201_015.png
#   inflating: /content/images/00021201_021.png
#   inflating: /content/images/00021201_044.png
#   inflating: /content/images/00021201_061.png
#   inflating: /content/images/00021201_072.png
#   inflating: /content/images/00021201_074.png
#   inflating: /content/images/00021201_073.png
#   inflating: /content/images/00021201_075.png
#   inflating: /content/images/00021201_078.png
#   inflating: /content/images/00021201_080.png
#   inflating: /content/images/00021201_081.png
#   inflating: /content/images/00021201_085.png
#   inflating: /content/images/00021201_090.png
#   inflating: /content/images/00021201_091.png
#   inflating: /content/images/00021201_092.png
#   inflating: /content/images/00021201_093.png
#   inflating: /content/images/00021201_098.png
#   inflating: /content/images/00021201_107.png
#   inflating: /content/images/00021201_109.png
#   inflating: /content/images/00021201_111.png
#   inflating: /content/images/00021201_112.png
#   inflating: /content/images/00021201_113.png
#   inflating: /content/images/00021209_001.png
#   inflating: /content/images/00021209_004.png
#   inflating: /content/images/00021212_002.png
#   inflating: /content/images/00021212_006.png
#   inflating: /content/images/00021213_001.png
#   inflating: /content/images/00021218_000.png
#   inflating: /content/images/00021219_001.png
#   inflating: /content/images/00021219_006.png
#   inflating: /content/images/00021219_007.png
#   inflating: /content/images/00021219_017.png
#   inflating: /content/images/00021220_002.png
#   inflating: /content/images/00021220_001.png
#   inflating: /content/images/00021222_002.png
#   inflating: /content/images/00021222_003.png
#   inflating: /content/images/00021222_004.png
#   inflating: /content/images/00021222_008.png
#   inflating: /content/images/00021222_011.png
#   inflating: /content/images/00021222_016.png
#   inflating: /content/images/00021222_018.png
#   inflating: /content/images/00021222_019.png
#   inflating: /content/images/00021226_001.png
#   inflating: /content/images/00021231_002.png
#   inflating: /content/images/00021236_004.png
#   inflating: /content/images/00021236_005.png
#   inflating: /content/images/00021242_000.png
#   inflating: /content/images/00021251_002.png
#   inflating: /content/images/00021251_004.png
#   inflating: /content/images/00021251_006.png
#   inflating: /content/images/00021251_007.png
#   inflating: /content/images/00021251_001.png
#   inflating: /content/images/00021252_000.png
#   inflating: /content/images/00021252_005.png
#   inflating: /content/images/00021252_006.png
#   inflating: /content/images/00021254_000.png
#   inflating: /content/images/00021254_006.png
#   inflating: /content/images/00021254_008.png
#   inflating: /content/images/00021255_007.png
#   inflating: /content/images/00021255_008.png
#   inflating: /content/images/00021255_000.png
#   inflating: /content/images/00021255_002.png
#   inflating: /content/images/00021255_003.png
#   inflating: /content/images/00021264_000.png
#   inflating: /content/images/00021264_002.png
#   inflating: /content/images/00021264_004.png
#   inflating: /content/images/00021264_005.png
#   inflating: /content/images/00021264_007.png
#   inflating: /content/images/00021274_009.png
#   inflating: /content/images/00021274_000.png
#   inflating: /content/images/00021274_001.png
#   inflating: /content/images/00021277_001.png
#   inflating: /content/images/00021277_002.png
#   inflating: /content/images/00021277_029.png
#   inflating: /content/images/00021282_003.png
#   inflating: /content/images/00021284_001.png
#   inflating: /content/images/00021284_002.png
#   inflating: /content/images/00021285_003.png
#   inflating: /content/images/00021287_000.png
#   inflating: /content/images/00021290_005.png
#   inflating: /content/images/00021290_000.png
#   inflating: /content/images/00021293_000.png
#   inflating: /content/images/00021294_001.png
#   inflating: /content/images/00021297_000.png
#   inflating: /content/images/00021298_000.png
#   inflating: /content/images/00021298_001.png
#   inflating: /content/images/00021299_000.png
#   inflating: /content/images/00021299_001.png
#   inflating: /content/images/00021299_002.png
#   inflating: /content/images/00021299_004.png
#   inflating: /content/images/00021303_003.png
#   inflating: /content/images/00021303_004.png
#   inflating: /content/images/00021303_002.png
#   inflating: /content/images/00021307_007.png
#   inflating: /content/images/00021307_012.png
#   inflating: /content/images/00021307_020.png
#   inflating: /content/images/00021311_000.png
#   inflating: /content/images/00021312_000.png
#   inflating: /content/images/00021312_001.png
#   inflating: /content/images/00021321_001.png
#   inflating: /content/images/00021321_004.png
#   inflating: /content/images/00021321_006.png
#   inflating: /content/images/00021321_007.png
#   inflating: /content/images/00021321_009.png
#   inflating: /content/images/00021321_011.png
#   inflating: /content/images/00021339_000.png
#   inflating: /content/images/00021340_000.png
#   inflating: /content/images/00021341_006.png
#   inflating: /content/images/00021341_007.png
#   inflating: /content/images/00021341_008.png
#   inflating: /content/images/00021341_009.png
#   inflating: /content/images/00021341_010.png
#   inflating: /content/images/00021341_012.png
#   inflating: /content/images/00021345_000.png
#   inflating: /content/images/00021345_001.png
#   inflating: /content/images/00021345_002.png
#   inflating: /content/images/00021345_003.png
#   inflating: /content/images/00021347_000.png
#   inflating: /content/images/00021351_000.png
#   inflating: /content/images/00021351_001.png
#   inflating: /content/images/00021361_004.png
#   inflating: /content/images/00021364_002.png
#   inflating: /content/images/00021367_000.png
#   inflating: /content/images/00021367_001.png
#   inflating: /content/images/00021367_002.png
#   inflating: /content/images/00021368_000.png
#   inflating: /content/images/00021369_000.png
#   inflating: /content/images/00021369_001.png
#   inflating: /content/images/00021373_001.png
#   inflating: /content/images/00021373_002.png
#   inflating: /content/images/00021373_003.png
#   inflating: /content/images/00021373_007.png
#   inflating: /content/images/00021373_008.png
#   inflating: /content/images/00021374_001.png
#   inflating: /content/images/00021374_002.png
#   inflating: /content/images/00021374_003.png
#   inflating: /content/images/00021374_006.png
#   inflating: /content/images/00021374_007.png
#   inflating: /content/images/00021374_009.png
#   inflating: /content/images/00021374_010.png
#   inflating: /content/images/00021374_011.png
#   inflating: /content/images/00021374_012.png
#   inflating: /content/images/00021374_014.png
#   inflating: /content/images/00021374_015.png
#   inflating: /content/images/00021374_017.png
#   inflating: /content/images/00021374_019.png
#   inflating: /content/images/00021374_023.png
#   inflating: /content/images/00021374_021.png
#   inflating: /content/images/00021374_022.png
#   inflating: /content/images/00021374_027.png
#   inflating: /content/images/00021374_028.png
#   inflating: /content/images/00021374_031.png
#   inflating: /content/images/00021374_032.png
#   inflating: /content/images/00021374_033.png
#   inflating: /content/images/00021377_002.png
#   inflating: /content/images/00021377_007.png
#   inflating: /content/images/00021377_008.png
#   inflating: /content/images/00021377_009.png
#   inflating: /content/images/00021377_010.png
#   inflating: /content/images/00021377_012.png
#   inflating: /content/images/00021377_013.png
#   inflating: /content/images/00021377_014.png
#   inflating: /content/images/00021377_015.png
#   inflating: /content/images/00021377_017.png
#   inflating: /content/images/00021377_018.png
#   inflating: /content/images/00021377_019.png
#   inflating: /content/images/00021377_020.png
#   inflating: /content/images/00021381_002.png
#   inflating: /content/images/00021381_003.png
#   inflating: /content/images/00021381_013.png
#   inflating: /content/images/00021381_014.png
#   inflating: /content/images/00021381_016.png
#   inflating: /content/images/00021381_017.png
#   inflating: /content/images/00021381_024.png
#   inflating: /content/images/00021381_027.png
#   inflating: /content/images/00021381_031.png
#   inflating: /content/images/00021381_033.png
#   inflating: /content/images/00021381_034.png
#   inflating: /content/images/00021381_036.png
#   inflating: /content/images/00021381_039.png
#   inflating: /content/images/00021383_005.png
#   inflating: /content/images/00021383_001.png
#   inflating: /content/images/00021383_002.png
#   inflating: /content/images/00021403_001.png
#   inflating: /content/images/00021403_002.png
#   inflating: /content/images/00021409_002.png
#   inflating: /content/images/00021409_006.png
#   inflating: /content/images/00021409_009.png
#   inflating: /content/images/00021414_001.png
#   inflating: /content/images/00021414_002.png
#   inflating: /content/images/00021420_006.png
#   inflating: /content/images/00021420_010.png
#   inflating: /content/images/00021420_014.png
#   inflating: /content/images/00021420_019.png
#   inflating: /content/images/00021420_020.png
#   inflating: /content/images/00021420_029.png
#   inflating: /content/images/00021431_000.png
#   inflating: /content/images/00021431_001.png
#   inflating: /content/images/00021431_005.png
#   inflating: /content/images/00021431_010.png
#   inflating: /content/images/00021434_000.png
#   inflating: /content/images/00021435_000.png
#   inflating: /content/images/00021435_001.png
#   inflating: /content/images/00021441_002.png
#   inflating: /content/images/00021441_003.png
#   inflating: /content/images/00021441_004.png
#   inflating: /content/images/00021448_001.png
#   inflating: /content/images/00021449_004.png
#   inflating: /content/images/00021455_005.png
#   inflating: /content/images/00021455_006.png
#   inflating: /content/images/00021455_007.png
#   inflating: /content/images/00021455_008.png
#   inflating: /content/images/00021455_009.png
#   inflating: /content/images/00021457_007.png
#   inflating: /content/images/00021457_010.png
#   inflating: /content/images/00021457_012.png
#   inflating: /content/images/00021457_013.png
#   inflating: /content/images/00021457_014.png
#   inflating: /content/images/00021457_017.png
#   inflating: /content/images/00021457_021.png
#   inflating: /content/images/00021457_023.png
#   inflating: /content/images/00021457_033.png
#   inflating: /content/images/00021457_035.png
#   inflating: /content/images/00021457_036.png
#   inflating: /content/images/00021457_039.png
#   inflating: /content/images/00021457_049.png
#   inflating: /content/images/00021457_050.png
#   inflating: /content/images/00021461_000.png
#   inflating: /content/images/00021469_001.png
#   inflating: /content/images/00021469_002.png
#   inflating: /content/images/00021469_003.png
#   inflating: /content/images/00021469_004.png
#   inflating: /content/images/00021470_000.png
#   inflating: /content/images/00021481_009.png
#   inflating: /content/images/00021481_013.png
#   inflating: /content/images/00021481_015.png
#   inflating: /content/images/00021481_017.png
#   inflating: /content/images/00021481_018.png
#   inflating: /content/images/00021481_019.png
#   inflating: /content/images/00021481_020.png
#   inflating: /content/images/00021484_000.png
#   inflating: /content/images/00021484_002.png
#   inflating: /content/images/00021487_000.png
#   inflating: /content/images/00021492_000.png
#   inflating: /content/images/00021494_025.png
#   inflating: /content/images/00021494_004.png
#   inflating: /content/images/00021494_007.png
#   inflating: /content/images/00021494_010.png
#   inflating: /content/images/00021494_016.png
#   inflating: /content/images/00021494_018.png
#   inflating: /content/images/00021494_019.png
#   inflating: /content/images/00021494_020.png
#   inflating: /content/images/00021495_003.png
#   inflating: /content/images/00021499_016.png
#   inflating: /content/images/00021499_018.png
#   inflating: /content/images/00021499_020.png
#   inflating: /content/images/00021499_024.png
#   inflating: /content/images/00021499_006.png
#   inflating: /content/images/00021500_000.png
#   inflating: /content/images/00021508_000.png
#   inflating: /content/images/00021508_003.png
#   inflating: /content/images/00021525_001.png
#   inflating: /content/images/00021537_000.png
#   inflating: /content/images/00021539_000.png
#   inflating: /content/images/00021539_001.png
#   inflating: /content/images/00021539_002.png
#   inflating: /content/images/00021547_000.png
#   inflating: /content/images/00021547_005.png
#   inflating: /content/images/00021552_020.png
#   inflating: /content/images/00021552_021.png
#   inflating: /content/images/00021552_004.png
#   inflating: /content/images/00021552_009.png
#   inflating: /content/images/00021557_000.png
#   inflating: /content/images/00021565_002.png
#   inflating: /content/images/00021565_003.png
#   inflating: /content/images/00021565_004.png
#   inflating: /content/images/00021565_007.png
#   inflating: /content/images/00021565_008.png
#   inflating: /content/images/00021565_009.png
#   inflating: /content/images/00021565_010.png
#   inflating: /content/images/00021565_012.png
#   inflating: /content/images/00021565_013.png
#   inflating: /content/images/00021565_014.png
#   inflating: /content/images/00021565_015.png
#   inflating: /content/images/00021565_016.png
#   inflating: /content/images/00021565_017.png
#   inflating: /content/images/00021565_018.png
#   inflating: /content/images/00021572_019.png
#   inflating: /content/images/00021572_012.png
#   inflating: /content/images/00021581_000.png
#   inflating: /content/images/00021581_001.png
#   inflating: /content/images/00021581_002.png
#   inflating: /content/images/00021582_002.png
#   inflating: /content/images/00021582_003.png
#   inflating: /content/images/00021582_004.png
#   inflating: /content/images/00021582_005.png
#   inflating: /content/images/00021582_006.png
#   inflating: /content/images/00021582_009.png
#   inflating: /content/images/00021584_010.png
#   inflating: /content/images/00021589_000.png
#   inflating: /content/images/00021590_000.png
#   inflating: /content/images/00021597_000.png
#   inflating: /content/images/00021600_003.png
#   inflating: /content/images/00021603_001.png
#   inflating: /content/images/00021609_003.png
#   inflating: /content/images/00021609_009.png
#   inflating: /content/images/00021610_008.png
#   inflating: /content/images/00021610_014.png
#   inflating: /content/images/00021610_015.png
#   inflating: /content/images/00021610_019.png
#   inflating: /content/images/00021610_025.png
#   inflating: /content/images/00021610_031.png
#   inflating: /content/images/00021610_000.png
#   inflating: /content/images/00021611_000.png
#   inflating: /content/images/00021611_002.png
#   inflating: /content/images/00021611_003.png
#   inflating: /content/images/00021611_005.png
#   inflating: /content/images/00021616_012.png
#   inflating: /content/images/00021616_000.png
#   inflating: /content/images/00021616_002.png
#   inflating: /content/images/00021616_008.png
#   inflating: /content/images/00021617_001.png
#   inflating: /content/images/00021618_005.png
#   inflating: /content/images/00021618_006.png
#   inflating: /content/images/00021618_007.png
#   inflating: /content/images/00021622_003.png
#   inflating: /content/images/00021622_000.png
#   inflating: /content/images/00021622_001.png
#   inflating: /content/images/00021626_005.png
#   inflating: /content/images/00021626_010.png
#   inflating: /content/images/00021626_011.png
#   inflating: /content/images/00021626_012.png
#   inflating: /content/images/00021627_000.png
#   inflating: /content/images/00021640_000.png
#   inflating: /content/images/00021640_001.png
#   inflating: /content/images/00021640_002.png
#   inflating: /content/images/00021640_004.png
#   inflating: /content/images/00021640_005.png
#   inflating: /content/images/00021648_009.png
#   inflating: /content/images/00021649_001.png
#   inflating: /content/images/00021651_001.png
#   inflating: /content/images/00021651_002.png
#   inflating: /content/images/00021651_003.png
#   inflating: /content/images/00021651_004.png
#   inflating: /content/images/00021651_006.png
#   inflating: /content/images/00021651_007.png
#   inflating: /content/images/00021651_008.png
#   inflating: /content/images/00021651_010.png
#   inflating: /content/images/00021651_013.png
#   inflating: /content/images/00021654_000.png
#   inflating: /content/images/00021669_000.png
#   inflating: /content/images/00021670_002.png
#   inflating: /content/images/00021670_024.png
#   inflating: /content/images/00021670_025.png
#   inflating: /content/images/00021672_000.png
#   inflating: /content/images/00021682_001.png
#   inflating: /content/images/00021682_002.png
#   inflating: /content/images/00021682_003.png
#   inflating: /content/images/00021687_001.png
#   inflating: /content/images/00021689_001.png
#   inflating: /content/images/00021693_000.png
#   inflating: /content/images/00021694_000.png
#   inflating: /content/images/00021695_000.png
#   inflating: /content/images/00021696_000.png
#   inflating: /content/images/00021700_004.png
#   inflating: /content/images/00021700_005.png
#   inflating: /content/images/00021700_006.png
#   inflating: /content/images/00021700_009.png
#   inflating: /content/images/00021700_011.png
#   inflating: /content/images/00021701_001.png
#   inflating: /content/images/00021703_000.png
#   inflating: /content/images/00021705_002.png
#   inflating: /content/images/00021706_003.png
#   inflating: /content/images/00021707_001.png
#   inflating: /content/images/00021707_002.png
#   inflating: /content/images/00021708_000.png
#   inflating: /content/images/00021711_016.png
#   inflating: /content/images/00021714_001.png
#   inflating: /content/images/00021726_003.png
#   inflating: /content/images/00021729_001.png
#   inflating: /content/images/00021735_002.png
#   inflating: /content/images/00021735_003.png
#   inflating: /content/images/00021748_003.png
#   inflating: /content/images/00021748_001.png
#   inflating: /content/images/00021748_000.png
#   inflating: /content/images/00021750_007.png
#   inflating: /content/images/00021750_010.png
#   inflating: /content/images/00021750_011.png
#   inflating: /content/images/00021759_010.png
#   inflating: /content/images/00021759_011.png
#   inflating: /content/images/00021759_015.png
#   inflating: /content/images/00021759_016.png
#   inflating: /content/images/00021759_022.png
#   inflating: /content/images/00021759_023.png
#   inflating: /content/images/00021759_024.png
#   inflating: /content/images/00021759_025.png
#   inflating: /content/images/00021759_027.png
#   inflating: /content/images/00021759_030.png
#   inflating: /content/images/00021759_002.png
#   inflating: /content/images/00021759_003.png
#   inflating: /content/images/00021759_004.png
#   inflating: /content/images/00021759_006.png
#   inflating: /content/images/00021763_003.png
#   inflating: /content/images/00021764_003.png
#   inflating: /content/images/00021770_008.png
#   inflating: /content/images/00021770_010.png
#   inflating: /content/images/00021770_012.png
#   inflating: /content/images/00021770_013.png
#   inflating: /content/images/00021770_014.png
#   inflating: /content/images/00021770_015.png
#   inflating: /content/images/00021770_017.png
#   inflating: /content/images/00021772_000.png
#   inflating: /content/images/00021772_001.png
#   inflating: /content/images/00021772_003.png
#   inflating: /content/images/00021772_005.png
#   inflating: /content/images/00021772_007.png
#   inflating: /content/images/00021772_010.png
#   inflating: /content/images/00021782_027.png
#   inflating: /content/images/00021782_028.png
#   inflating: /content/images/00021782_031.png
#   inflating: /content/images/00021782_002.png
#   inflating: /content/images/00021782_010.png
#   inflating: /content/images/00021784_003.png
#   inflating: /content/images/00021784_002.png
#   inflating: /content/images/00021786_000.png
#   inflating: /content/images/00021787_000.png
#   inflating: /content/images/00021791_002.png
#   inflating: /content/images/00021791_003.png
#   inflating: /content/images/00021795_000.png
#   inflating: /content/images/00021796_001.png
#   inflating: /content/images/00021796_007.png
#   inflating: /content/images/00021796_009.png
#   inflating: /content/images/00021796_011.png
#   inflating: /content/images/00021796_012.png
#   inflating: /content/images/00021802_000.png
#   inflating: /content/images/00021802_001.png
#   inflating: /content/images/00021806_002.png
#   inflating: /content/images/00021806_003.png
#   inflating: /content/images/00021808_001.png
#   inflating: /content/images/00021808_002.png
#   inflating: /content/images/00021808_003.png
#   inflating: /content/images/00021810_001.png
#   inflating: /content/images/00021811_002.png
#   inflating: /content/images/00021813_001.png
#   inflating: /content/images/00021817_002.png
#   inflating: /content/images/00021817_004.png
#   inflating: /content/images/00021818_011.png
#   inflating: /content/images/00021818_013.png
#   inflating: /content/images/00021821_000.png
#   inflating: /content/images/00021821_001.png
#   inflating: /content/images/00021821_002.png
#   inflating: /content/images/00021821_004.png
#   inflating: /content/images/00021821_005.png
#   inflating: /content/images/00021821_006.png
#   inflating: /content/images/00021828_000.png
#   inflating: /content/images/00021828_001.png
#   inflating: /content/images/00021828_002.png
#   inflating: /content/images/00021835_007.png
#   inflating: /content/images/00021835_014.png
#   inflating: /content/images/00021835_024.png
#   inflating: /content/images/00021835_025.png
#   inflating: /content/images/00021835_026.png
#   inflating: /content/images/00021835_032.png
#   inflating: /content/images/00021840_000.png
#   inflating: /content/images/00021840_002.png
#   inflating: /content/images/00021840_006.png
#   inflating: /content/images/00021840_007.png
#   inflating: /content/images/00021840_009.png
#   inflating: /content/images/00021840_016.png
#   inflating: /content/images/00021840_021.png
#   inflating: /content/images/00021840_022.png
#   inflating: /content/images/00021856_000.png
#   inflating: /content/images/00021860_008.png
#   inflating: /content/images/00021865_000.png
#   inflating: /content/images/00021865_001.png
#   inflating: /content/images/00021888_005.png
#   inflating: /content/images/00021889_000.png
#   inflating: /content/images/00021889_001.png
#   inflating: /content/images/00021889_007.png
#   inflating: /content/images/00021889_008.png
#   inflating: /content/images/00021896_002.png
#   inflating: /content/images/00021896_003.png
#   inflating: /content/images/00021896_007.png
#   inflating: /content/images/00021901_002.png
#   inflating: /content/images/00021901_000.png
#   inflating: /content/images/00021903_001.png
#   inflating: /content/images/00021911_000.png
#   inflating: /content/images/00021926_004.png
#   inflating: /content/images/00021926_008.png
#   inflating: /content/images/00021926_009.png
#   inflating: /content/images/00021937_000.png
#   inflating: /content/images/00021939_000.png
#   inflating: /content/images/00021939_001.png
#   inflating: /content/images/00021939_004.png
#   inflating: /content/images/00021939_006.png
#   inflating: /content/images/00021939_007.png
#   inflating: /content/images/00021939_009.png
#   inflating: /content/images/00021940_000.png
#   inflating: /content/images/00021942_000.png
#   inflating: /content/images/00021942_016.png
#   inflating: /content/images/00021944_000.png
#   inflating: /content/images/00021953_000.png
#   inflating: /content/images/00021954_001.png
#   inflating: /content/images/00021954_002.png
#   inflating: /content/images/00021954_003.png
#   inflating: /content/images/00021954_006.png
#   inflating: /content/images/00021956_003.png
#   inflating: /content/images/00021965_001.png
#   inflating: /content/images/00021967_000.png
#   inflating: /content/images/00021968_002.png
#   inflating: /content/images/00021968_003.png
#   inflating: /content/images/00021968_009.png
#   inflating: /content/images/00021970_006.png
#   inflating: /content/images/00021970_000.png
#   inflating: /content/images/00021972_013.png
#   inflating: /content/images/00021972_017.png
# ...
#   inflating: /content/images/00029959_005.png
#   inflating: /content/images/00029969_001.png
#   inflating: /content/images/00029970_001.png
#   inflating: /content/images/00029971_000.png
#   inflating: /content/images/00029976_001.png
#   inflating: /content/images/00029976_005.png
#   inflating: /content/images/00029976_010.png
#   inflating: /content/images/00029976_011.png
#   inflating: /content/images/00029984_000.png
#   inflating: /content/images/00029984_005.png
#   inflating: /content/images/00029984_008.png
#   inflating: /content/images/00029985_000.png
#   inflating: /content/images/00029985_003.png
#   inflating: /content/images/00029989_000.png
#   inflating: /content/images/00029991_009.png
#   inflating: /content/images/00029991_011.png
#   inflating: /content/images/00029991_013.png
#   inflating: /content/images/00029993_000.png
#   inflating: /content/images/00029998_008.png
#   inflating: /content/images/00029998_006.png
#   inflating: /content/images/00029998_012.png
#   inflating: /content/images/00029998_013.png
#   inflating: /content/images/00030000_003.png
#   inflating: /content/images/00030011_000.png
#   inflating: /content/images/00030023_004.png
#   inflating: /content/images/00030025_001.png
#   inflating: /content/images/00030025_002.png
#   inflating: /content/images/00030026_000.png
#   inflating: /content/images/00030028_001.png
#   inflating: /content/images/00030030_004.png
#   inflating: /content/images/00030038_007.png
#   inflating: /content/images/00030038_010.png
#   inflating: /content/images/00030038_012.png
#   inflating: /content/images/00030038_011.png
#   inflating: /content/images/00030039_000.png
#   inflating: /content/images/00030039_009.png
#   inflating: /content/images/00030039_010.png
#   inflating: /content/images/00030045_000.png
#   inflating: /content/images/00030046_008.png
#   inflating: /content/images/00030047_000.png
#   inflating: /content/images/00030054_000.png
#   inflating: /content/images/00030059_001.png
#   inflating: /content/images/00030059_005.png
#   inflating: /content/images/00030059_006.png
#   inflating: /content/images/00030059_007.png
#   inflating: /content/images/00030059_011.png
#   inflating: /content/images/00030063_000.png
#   inflating: /content/images/00030063_001.png
#   inflating: /content/images/00030068_002.png
#   inflating: /content/images/00030070_000.png
#   inflating: /content/images/00030072_000.png
#   inflating: /content/images/00030076_000.png
#   inflating: /content/images/00030077_001.png
#   inflating: /content/images/00030077_002.png
#   inflating: /content/images/00030077_003.png
#   inflating: /content/images/00030077_009.png
#   inflating: /content/images/00030077_010.png
#   inflating: /content/images/00030077_012.png
#   inflating: /content/images/00030078_000.png
#   inflating: /content/images/00030079_003.png
#   inflating: /content/images/00030079_008.png
#   inflating: /content/images/00030079_011.png
#   inflating: /content/images/00030079_013.png
#   inflating: /content/images/00030079_015.png
#   inflating: /content/images/00030079_021.png
#   inflating: /content/images/00030079_023.png
#   inflating: /content/images/00030079_028.png
#   inflating: /content/images/00030079_032.png
#   inflating: /content/images/00030079_034.png
#   inflating: /content/images/00030079_043.png
#   inflating: /content/images/00030079_049.png
#   inflating: /content/images/00030079_065.png
#   inflating: /content/images/00030096_000.png
#   inflating: /content/images/00030102_000.png
#   inflating: /content/images/00030102_001.png
#   inflating: /content/images/00030105_001.png
#   inflating: /content/images/00030106_000.png
#   inflating: /content/images/00030107_004.png
#   inflating: /content/images/00030111_000.png
#   inflating: /content/images/00030111_001.png
#   inflating: /content/images/00030111_002.png
#   inflating: /content/images/00030111_005.png
#   inflating: /content/images/00030111_007.png
#   inflating: /content/images/00030111_015.png
#   inflating: /content/images/00030121_001.png
#   inflating: /content/images/00030128_003.png
#   inflating: /content/images/00030129_004.png
#   inflating: /content/images/00030134_001.png
#   inflating: /content/images/00030137_001.png
#   inflating: /content/images/00030137_004.png
#   inflating: /content/images/00030137_006.png
#   inflating: /content/images/00030152_006.png
#   inflating: /content/images/00030152_008.png
#   inflating: /content/images/00030152_009.png
#   inflating: /content/images/00030153_003.png
#   inflating: /content/images/00030153_004.png
#   inflating: /content/images/00030157_001.png
#   inflating: /content/images/00030157_002.png
#   inflating: /content/images/00030158_000.png
#   inflating: /content/images/00030158_002.png
#   inflating: /content/images/00030158_005.png
#   inflating: /content/images/00030159_000.png
#   inflating: /content/images/00030159_001.png
#   inflating: /content/images/00030159_007.png
#   inflating: /content/images/00030159_010.png
#   inflating: /content/images/00030159_012.png
#   inflating: /content/images/00030159_014.png
#   inflating: /content/images/00030162_002.png
#   inflating: /content/images/00030162_005.png
#   inflating: /content/images/00030162_006.png
#   inflating: /content/images/00030162_008.png
#   inflating: /content/images/00030162_012.png
#   inflating: /content/images/00030162_019.png
#   inflating: /content/images/00030167_001.png
#   inflating: /content/images/00030167_002.png
#   inflating: /content/images/00030167_004.png
#   inflating: /content/images/00030180_000.png
#   inflating: /content/images/00030183_000.png
#   inflating: /content/images/00030183_001.png
#   inflating: /content/images/00030183_002.png
#   inflating: /content/images/00030183_006.png
#   inflating: /content/images/00030184_003.png
#   inflating: /content/images/00030196_000.png
#   inflating: /content/images/00030202_000.png
#   inflating: /content/images/00030206_006.png
#   inflating: /content/images/00030206_007.png
#   inflating: /content/images/00030206_009.png
#   inflating: /content/images/00030206_010.png
#   inflating: /content/images/00030206_012.png
#   inflating: /content/images/00030208_000.png
#   inflating: /content/images/00030214_001.png
#   inflating: /content/images/00030226_000.png
#   inflating: /content/images/00030234_000.png
#   inflating: /content/images/00030234_001.png
#   inflating: /content/images/00030235_004.png
#   inflating: /content/images/00030247_002.png
#   inflating: /content/images/00030247_003.png
#   inflating: /content/images/00030247_004.png
#   inflating: /content/images/00030247_010.png
#   inflating: /content/images/00030253_000.png
#   inflating: /content/images/00030267_001.png
#   inflating: /content/images/00030267_002.png
#   inflating: /content/images/00030268_001.png
#   inflating: /content/images/00030270_000.png
#   inflating: /content/images/00030271_000.png
#   inflating: /content/images/00030279_002.png
#   inflating: /content/images/00030279_004.png
#   inflating: /content/images/00030279_009.png
#   inflating: /content/images/00030279_010.png
#   inflating: /content/images/00030279_011.png
#   inflating: /content/images/00030280_002.png
#   inflating: /content/images/00030280_003.png
#   inflating: /content/images/00030282_000.png
#   inflating: /content/images/00030284_000.png
#   inflating: /content/images/00030300_002.png
#   inflating: /content/images/00030300_005.png
#   inflating: /content/images/00030300_007.png
#   inflating: /content/images/00030301_000.png
#   inflating: /content/images/00030305_000.png
#   inflating: /content/images/00030305_004.png
#   inflating: /content/images/00030319_000.png
#   inflating: /content/images/00030320_004.png
#   inflating: /content/images/00030323_000.png
#   inflating: /content/images/00030323_002.png
#   inflating: /content/images/00030323_003.png
#   inflating: /content/images/00030323_012.png
#   inflating: /content/images/00030323_016.png
#   inflating: /content/images/00030323_017.png
#   inflating: /content/images/00030323_022.png
#   inflating: /content/images/00030323_021.png
#   inflating: /content/images/00030323_023.png
#   inflating: /content/images/00030323_024.png
#   inflating: /content/images/00030323_025.png
#   inflating: /content/images/00030323_030.png
#   inflating: /content/images/00030323_034.png
#   inflating: /content/images/00030323_041.png
#   inflating: /content/images/00030323_042.png
#   inflating: /content/images/00030323_044.png
#   inflating: /content/images/00030327_000.png
#   inflating: /content/images/00030334_000.png
#   inflating: /content/images/00030337_000.png
#   inflating: /content/images/00030338_002.png
#   inflating: /content/images/00030339_007.png
#   inflating: /content/images/00030339_008.png
#   inflating: /content/images/00030346_002.png
#   inflating: /content/images/00030346_003.png
#   inflating: /content/images/00030346_007.png
#   inflating: /content/images/00030350_000.png
#   inflating: /content/images/00030362_000.png
#   inflating: /content/images/00030365_001.png
#   inflating: /content/images/00030370_002.png
#   inflating: /content/images/00030370_004.png
#   inflating: /content/images/00030375_003.png
#   inflating: /content/images/00030375_004.png
#   inflating: /content/images/00030376_000.png
#   inflating: /content/images/00030379_001.png
#   inflating: /content/images/00030379_002.png
#   inflating: /content/images/00030389_000.png
#   inflating: /content/images/00030389_007.png
#   inflating: /content/images/00030389_009.png
#   inflating: /content/images/00030408_000.png
#   inflating: /content/images/00030408_005.png
#   inflating: /content/images/00030408_006.png
#   inflating: /content/images/00030408_008.png
#   inflating: /content/images/00030408_014.png
#   inflating: /content/images/00030408_015.png
#   inflating: /content/images/00030408_016.png
#   inflating: /content/images/00030408_017.png
#   inflating: /content/images/00030410_000.png
#   inflating: /content/images/00030410_002.png
#   inflating: /content/images/00030410_004.png
#   inflating: /content/images/00030410_007.png
#   inflating: /content/images/00030413_000.png
#   inflating: /content/images/00030434_000.png
#   inflating: /content/images/00030434_001.png
#   inflating: /content/images/00030436_000.png
#   inflating: /content/images/00030439_002.png
#   inflating: /content/images/00030439_003.png
#   inflating: /content/images/00030439_005.png
#   inflating: /content/images/00030439_007.png
#   inflating: /content/images/00030454_000.png
#   inflating: /content/images/00030481_000.png
#   inflating: /content/images/00030488_001.png
#   inflating: /content/images/00030488_000.png
#   inflating: /content/images/00030497_004.png
#   inflating: /content/images/00030497_005.png
#   inflating: /content/images/00030497_006.png
#   inflating: /content/images/00030499_000.png
#   inflating: /content/images/00030499_001.png
#   inflating: /content/images/00030499_003.png
#   inflating: /content/images/00030499_006.png
#   inflating: /content/images/00030506_000.png
#   inflating: /content/images/00030519_001.png
#   inflating: /content/images/00030536_000.png
#   inflating: /content/images/00030536_001.png
#   inflating: /content/images/00030541_000.png
#   inflating: /content/images/00030541_002.png
#   inflating: /content/images/00030546_000.png
#   inflating: /content/images/00030550_001.png
#   inflating: /content/images/00030561_005.png
#   inflating: /content/images/00030561_007.png
#   inflating: /content/images/00030561_010.png
#   inflating: /content/images/00030561_011.png
#   inflating: /content/images/00030561_013.png
#   inflating: /content/images/00030561_014.png
#   inflating: /content/images/00030561_017.png
#   inflating: /content/images/00030561_018.png
#   inflating: /content/images/00030571_001.png
#   inflating: /content/images/00030571_002.png
#   inflating: /content/images/00030573_009.png
#   inflating: /content/images/00030573_013.png
#   inflating: /content/images/00030573_017.png
#   inflating: /content/images/00030582_001.png
#   inflating: /content/images/00030582_003.png
#   inflating: /content/images/00030586_000.png
#   inflating: /content/images/00030592_000.png
#   inflating: /content/images/00030594_000.png
#   inflating: /content/images/00030601_000.png
#   inflating: /content/images/00030604_002.png
#   inflating: /content/images/00030606_000.png
#   inflating: /content/images/00030606_001.png
#   inflating: /content/images/00030606_002.png
#   inflating: /content/images/00030606_005.png
#   inflating: /content/images/00030606_007.png
#   inflating: /content/images/00030606_009.png
#   inflating: /content/images/00030606_013.png
#   inflating: /content/images/00030606_014.png
#   inflating: /content/images/00030609_011.png
#   inflating: /content/images/00030609_014.png
#   inflating: /content/images/00030609_020.png
#   inflating: /content/images/00030609_021.png
#   inflating: /content/images/00030615_002.png
#   inflating: /content/images/00030628_001.png
#   inflating: /content/images/00030628_002.png
#   inflating: /content/images/00030628_003.png
#   inflating: /content/images/00030631_001.png
#   inflating: /content/images/00030634_000.png
#   inflating: /content/images/00030635_004.png
#   inflating: /content/images/00030636_000.png
#   inflating: /content/images/00030636_001.png
#   inflating: /content/images/00030636_002.png
#   inflating: /content/images/00030636_004.png
#   inflating: /content/images/00030636_009.png
#   inflating: /content/images/00030636_010.png
#   inflating: /content/images/00030636_012.png
#   inflating: /content/images/00030636_023.png
#   inflating: /content/images/00030637_000.png
#   inflating: /content/images/00030637_004.png
#   inflating: /content/images/00030637_010.png
#   inflating: /content/images/00030637_012.png
#   inflating: /content/images/00030637_017.png
#   inflating: /content/images/00030637_018.png
#   inflating: /content/images/00030637_019.png
#   inflating: /content/images/00030638_000.png
#   inflating: /content/images/00030640_000.png
#   inflating: /content/images/00030650_009.png
#   inflating: /content/images/00030652_004.png
#   inflating: /content/images/00030661_000.png
#   inflating: /content/images/00030672_002.png
#   inflating: /content/images/00030674_000.png
#   inflating: /content/images/00030679_000.png
#   inflating: /content/images/00030679_001.png
#   inflating: /content/images/00030682_000.png
#   inflating: /content/images/00030683_000.png
#   inflating: /content/images/00030683_001.png
#   inflating: /content/images/00030689_000.png
#   inflating: /content/images/00030689_001.png
#   inflating: /content/images/00030689_003.png
#   inflating: /content/images/00030689_004.png
#   inflating: /content/images/00030692_000.png
#   inflating: /content/images/00030693_001.png
#   inflating: /content/images/00030695_000.png
#   inflating: /content/images/00030695_001.png
#   inflating: /content/images/00030695_002.png
#   inflating: /content/images/00030695_003.png
#   inflating: /content/images/00030697_000.png
#   inflating: /content/images/00030699_000.png
#   inflating: /content/images/00030703_000.png
#   inflating: /content/images/00030703_001.png
#   inflating: /content/images/00030722_000.png
#   inflating: /content/images/00030726_000.png
#   inflating: /content/images/00030733_002.png
#   inflating: /content/images/00030753_000.png
#   inflating: /content/images/00030753_008.png
#   inflating: /content/images/00030753_011.png
#   inflating: /content/images/00030759_000.png
#   inflating: /content/images/00030760_000.png
#   inflating: /content/images/00030772_001.png
#   inflating: /content/images/00030772_002.png
#   inflating: /content/images/00030774_000.png
#   inflating: /content/images/00030780_000.png
#   inflating: /content/images/00030786_000.png
#   inflating: /content/images/00030786_006.png

# %%
#@title import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

warnings.filterwarnings(action="ignore")

import torch
import torch.nn as nn
import torchvision
from torchvision import transforms, models
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import roc_auc_score
from PIL import Image
from tqdm import tqdm

import random
def set_seed(seed):
    """Set seeds for reproducibility."""
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    print(f"Seed set to {seed}")

set_seed(42)
# Out:
# Seed set to 42

# %% [markdown]
# ## Load data

# %%
# Load the data splits
DATA_PATH = '/content' # Ensure this path is correct
train_df = pd.read_csv(f'{DATA_PATH}/train_df.csv')
val_df = pd.read_csv(f'{DATA_PATH}/val_df.csv')
test_df = pd.read_csv(f'{DATA_PATH}/test_df.csv') # Renaming to test_df for clarity

IMG_DIR = f'{DATA_PATH}/images'
train_df['ImagePath'] = train_df['Image Index'].apply(lambda x: os.path.join(IMG_DIR, x))
val_df['ImagePath'] = val_df['Image Index'].apply(lambda x: os.path.join(IMG_DIR, x))
test_df['ImagePath'] = test_df['Image Index'].apply(lambda x: os.path.join(IMG_DIR, x))

print("Data loaded successfully.")
print("Training samples:", len(train_df))
print("Validation samples:", len(val_df))
print("Test samples:", len(test_df))
# Out:
# Data loaded successfully.
# Training samples: 2160
# Validation samples: 540
# Test samples: 558

# %% [markdown]
# ## Preprocessing Tabular Data

# %% [markdown]
# Before we can feed our demographic data into a neural network, it needs to be preprocessed into a numerical format.
# *   Patient Age: This is a continuous feature. We will normalize it to a range between 0 and 1 to help with stable model training.
# *   Patient Sex: This is a categorical feature ('M' or 'F'). We will convert it into a one-hot encoded vector. For example, `F` becomes `[1, 0]` and `M` becomes `[0, 1]`.
#
# Your first task is to preprocess the demographic data

# %%
# Normalize Age
# We'll use the min and max age from the training set for normalization
min_age = train_df['Patient Age'].min()
max_age = train_df['Patient Age'].max()

def normalize_age(age):
    norm_age = (age - min_age)/(max_age - min_age) # COMPLETE: Normalize the age using min_age and max_age
    return norm_age # COMPLETE

# One-Hot Encode Sex
def one_hot_sex(sex):
    if sex == 'F':
        return [1, 0]
    elif sex == 'M':
        return [0, 1]
    else:
        # Optional: Handle unexpected values gracefully
        return [0, 0]

# %%
sample_row = train_df.iloc[0]
age_norm = normalize_age(sample_row['Patient Age'])
sex_onehot = one_hot_sex(sample_row['Patient Sex'])
tabular_vector = np.array([age_norm] + sex_onehot, dtype=np.float32)

print(f"Sample Patient Age: {sample_row['Patient Age']}, Sex: {sample_row['Patient Sex']}")
print(f"Processed Tabular Vector: {tabular_vector}")
print(f"Size of our tabular feature vector: {len(tabular_vector)}")
# Out:
# Sample Patient Age: 63, Sex: F
# Processed Tabular Vector: [0.7126437 1.        0.       ]
# Size of our tabular feature vector: 3

# %% [markdown]
# ## Creating the `MultiModalDataset`
#
# Now, create a custom PyTorch `Dataset`. This class needs to return three items for each sample: the image tensor, the processed tabular vector, and the label.
#
# Complete the `__getitem__` method to process and return the correct tensors.

# %%
class MultiModalDataset(Dataset):
    def __init__(self, df, is_train=True):
        self.df = df
        self.image_paths = df['ImagePath'].tolist()
        self.ages = df['Patient Age'].tolist()
        self.sexes = df['Patient Sex'].tolist()
        self.labels = df['Binary Label'].tolist()

        mean, std = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]
        if is_train:
            self.transform = transforms.Compose([
                transforms.Resize((224, 224)),
                transforms.RandomHorizontalFlip(),
                transforms.RandomRotation(10),
                transforms.ToTensor(),
                transforms.Normalize(mean, std)
            ])
        else:
            self.transform = transforms.Compose([
                transforms.Resize((224, 224)),
                transforms.ToTensor(),
                transforms.Normalize(mean, std)
            ])

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        # Image Processing
        image = Image.open(self.image_paths[idx]).convert('RGB')
        image_tensor = self.transform(image)

        # COMPLETE: Tabular Data Processing
        # 1. Get the normalized age for the patient at index `idx`
        # 2. Get the one-hot encoded sex for the patient at index `idx`
        # 3. Combine them into a single tensor named `tabular_tensor`
        age_norm = normalize_age(self.ages[idx]) # COMPLETE
        sex_onehot = one_hot_sex(self.sexes[idx])# COMPLETE
        tabular_tensor = torch.tensor([age_norm] + sex_onehot, dtype=torch.float32) # COMPLETE

        # Label
        label = torch.tensor(self.labels[idx], dtype=torch.float32)

        return image_tensor, tabular_tensor, label

# %% [markdown]
# Define the `MultiModalDataset` and `Datalaoders`

# %%
# Create datasets
train_dataset = MultiModalDataset(train_df, is_train=True)
val_dataset = MultiModalDataset(val_df, is_train=False)
test_dataset = MultiModalDataset(test_df, is_train=True)

# Create dataloaders with drop_last=True to avoid the shape mismatch error
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=4,
    drop_last=True
)
val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=4,
    drop_last=False
)
test_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=4,
    drop_last=False
)

# %% [markdown]
# ### Building the Fusion Models
#
#
# #### The Image Feature Extractor
#
# Both of our fusion models will use a pre-trained `DenseNet-121` as a backbone to extract high-level features from the chest X-rays. We will freeze the majority of its layers to prevent the pre-trained weights from being altered too much during our short training session.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def get_image_backbone():
    # Load pre-trained DenseNet-121
    densenet = models.densenet121()
    densenet.classifier = nn.Linear(densenet.classifier.in_features, 1)
    densenet.load_state_dict(torch.load('./densenet121-classification.pth', map_location=device))

    # Freeze all layers
    for param in densenet.parameters():
        param.requires_grad = False

    # Unfreeze the final dense block and the classifier to fine-tune
    for param in densenet.features.denseblock4.parameters():
        param.requires_grad = True

    # Get the number of output features from the backbone
    num_features = densenet.classifier.in_features

    # Remove the final classifier layer
    densenet.classifier = nn.Identity()

    return densenet, num_features

# Test it
backbone, num_img_features = get_image_backbone()
print(f"DenseNet backbone loaded. Output feature size: {num_img_features}")
# Out:
# DenseNet backbone loaded. Output feature size: 1024

# %% [markdown]
# #### Model 1: Concatenation-based Fusion
#
# This is our first fusion model. The strategy is straightforward:
# 1.  Extract a feature vector from the image using our `DenseNet` backbone.
# 2.  Process the tabular data through its own small neural network (an MLP).
# 3.  Concatenate the two resulting feature vectors.
# 4.  Pass this final combined vector through a classifier to get a prediction.
#
# You will implement the `forward` pass for three different fusion architectures as described in the lecture. The `__init__` methods are provided for you.
#
# Your task is to complete the `forward` method for each of the three models below.

# %%
class ConcatenationModel(nn.Module):
    def __init__(self, num_img_features, num_tabular_features, hidden_size=128):
        super().__init__()
        self.image_backbone, _ = get_image_backbone()
        self.tabular_mlp = nn.Sequential(nn.Linear(num_tabular_features, hidden_size), nn.ReLU(), nn.Linear(hidden_size, hidden_size))
        self.classifier = nn.Sequential(nn.Linear(num_img_features + hidden_size, 128), nn.ReLU(), nn.Dropout(0.2), nn.Linear(128, 1))

    def forward(self, image, tabular_data):
        # 1. Get image features from the backbone
        img_features = self.image_backbone(image)
        # 2. Get tabular features from the tabular MLP
        tab_features = self.tabular_mlp(tabular_data)

        # COMPLETE: 3. Concatenate the two feature vectors along dimension 1
        combined_features = torch.cat([img_features, tab_features], dim =1) # COMPLETE

        # 4. Pass the combined features through the classifier
        output = self.classifier(combined_features)
        return output

# %% [markdown]
# #### Model 2: Attention-based Fusion (Gated Multi-Modal Unit)
#
# Our second model is more advanced. Instead of just combining features, it uses the tabular data to create a "gating" mechanism that modulates the image features. The model learns which visual patterns are more or less important based on the patient's age and sex.
#
# 1.  Extract image features.
# 2.  Process tabular data to get tabular features.
# 3.  Pass the tabular features through a `sigmoid` function to create a "gate" vector with values between 0 and 1.
# 4.  Multiply the image features by this gate (element-wise). This is the attention mechanism.
# 5.  Concatenate the *gated* image features with the original tabular features.
# 6.  Pass the result through the final classifier.

# %%
class AttentionFusionModel(nn.Module):
    def __init__(self, num_img_features, num_tabular_features, hidden_size=128):
        super().__init__()
        self.image_backbone, _ = get_image_backbone()
        self.tabular_mlp = nn.Sequential(nn.Linear(num_tabular_features, hidden_size), nn.ReLU())
        self.gate = nn.Sequential(nn.Linear(hidden_size, num_img_features), nn.Sigmoid())
        self.classifier = nn.Sequential(nn.Linear(num_img_features + hidden_size, 128), nn.ReLU(), nn.Dropout(0.2), nn.Linear(128, 1))

    def forward(self, image, tabular_data):
        img_features = self.image_backbone(image)
        tab_features = self.tabular_mlp(tabular_data)

        # COMPLETE:
        # 1. Generate the attention gate from the tabular features
        attention_gate = self.gate(tab_features) # COMPLETE
        # 2. Apply the gate to the image features (element-wise multiplication)
        gated_img_features = img_features * attention_gate # COMPLETE
        # 3. Concatenate the *gated* image features with the original tabular features
        combined_features = torch.cat((gated_img_features, tab_features), dim=1) # COMPLETE

        output = self.classifier(combined_features)
        return output

# %% [markdown]
# #### Model 3: Attention-based Fusion (Gated Multi-Modal Unit)
#
# Bilinear Pooling Fusion
#
# This model uses Bilinear Pooling to capture more expressive feature interactions. Unlike concatenation, which simply appends feature vectors, bilinear pooling computes the outer product of the image and tabular features. This creates a much richer representation that explicitly models the multiplicative (or pairwise) interaction between every feature from the image and every feature from the metadata.
#
# 1.  Extract image features using the `DenseNet` backbone.
# 2.  Process tabular data through its own MLP to get tabular features.
# 3.  A `Bilinear` layer combines the image and tabular features, considering all pairwise products.
# 4.  The output is passed to a final classifier. This method is computationally more intensive but can capture complex feature correlations.

# %%
class BilinearFusionModel(nn.Module):
    def __init__(self, num_img_features, num_tabular_features, hidden_size=128, output_size=512):
        super().__init__()
        self.image_backbone, _ = get_image_backbone()
        self.tabular_mlp = nn.Sequential(nn.Linear(num_tabular_features, hidden_size), nn.ReLU())
        self.bilinear = nn.Bilinear(num_img_features, hidden_size, output_size)
        self.classifier = nn.Sequential(nn.ReLU(), nn.Dropout(0.2), nn.Linear(output_size, 1))

    def forward(self, image, tabular_data):
        img_features = self.image_backbone(image)
        tab_features = self.tabular_mlp(tabular_data)

        # COMPLETE:
        # 1. Apply the bilinear layer to the image and tabular features
        fused_features = self.bilinear(img_features, tab_features) # COMPLETE

        output = self.classifier(fused_features)
        return output

# %% [markdown]
# ### Training and Evaluation
#
# #### Training and Validation Loop
#
# We'll define our training and validation functions. We will train each model for a small number of epochs (3-5) and monitor the validation AUC at the end of each epoch.
#
# Now you will train the models you just built. The training and validation helper functions are provided.
#
# Your task is to instantiate the three models and then run the training loop.

# %%
def train_one_epoch(model, dataloader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for images, tabular, labels in tqdm(dataloader, desc="Training"):
        images, tabular, labels = images.to(device), tabular.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images, tabular)
        loss = criterion(outputs.squeeze(), labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    return total_loss / len(dataloader)

def validate(model, dataloader, device):
    model.eval()
    all_labels = []
    all_probs = []
    with torch.no_grad():
        for images, tabular, labels in tqdm(dataloader, desc="Validating"):
            images, tabular = images.to(device), tabular.to(device)

            outputs = model(images, tabular)
            probs = torch.sigmoid(outputs.squeeze())

            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return all_labels, all_probs

# %% [markdown]
# # Training Setup

# %% [markdown]
# #### Train the Concatenation Model

# %%
# Load the saved model
concat_model = ConcatenationModel(
    num_img_features=num_img_features,
    num_tabular_features=len(tabular_vector)
).to(device)

concat_model.load_state_dict(torch.load('concat_model_best_auc.pth', map_location=device))
concat_model.eval() # Set the model to evaluation mode
print("Concatenation Model loaded successfully.")
# Out:
# Concatenation Model loaded successfully.

# %%
from sklearn.metrics import (
    roc_auc_score,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)
# COMPLETE: Instantiate
print("--- Training Concatenation Model ---")
concat_model = ConcatenationModel(
    num_img_features=num_img_features,
    num_tabular_features=len(tabular_vector)
).to(device)


optimizer_concat = torch.optim.Adam(concat_model.parameters(), lr=1e-4) # COMPLETE
criterion = nn.BCEWithLogitsLoss() # COMPLETE

num_epochs = 10 # COMPLETE
concat_aucs = []
concat_accuracies = []
concat_precisions = []
concat_recalls = []
concat_f1s = []

best_auc = 0.0
best_model_state = None

for epoch in range(num_epochs):
    train_loss = train_one_epoch(
        concat_model, train_loader, optimizer_concat, criterion, device
    )

    # Validation
    all_labels, all_probs = validate(concat_model, val_loader, device) # COMPLETE)
    val_auc = roc_auc_score(all_labels, all_probs) # COMPLETE)

    all_labels = np.array(all_labels)
    all_probs  = np.array(all_probs)

    # Binarize probs at 0.5
    val_preds = (all_probs >= 0.5).astype(int)

    # Compute other metrics
    val_acc   = accuracy_score(all_labels, val_preds)
    val_prec  = precision_score(all_labels, val_preds, zero_division=0)
    val_rec   = recall_score(all_labels, val_preds, zero_division=0)
    val_f1    = f1_score(all_labels, val_preds, zero_division=0)

    # Store for plotting later
    concat_aucs.append(val_auc)
    concat_accuracies.append(val_acc)
    concat_precisions.append(val_prec)
    concat_recalls.append(val_rec)
    concat_f1s.append(val_f1)

    # Print epoch summary
    print(
        f"Epoch {epoch+1}/{num_epochs} — "
        f"Train Loss: {train_loss:.4f} | "
        f"Val AUC: {val_auc:.4f} | "
        f"Acc: {val_acc:.4f} | "
        f"Prec: {val_prec:.4f} | "
        f"Rec: {val_rec:.4f} | "
        f"F1: {val_f1:.4f}"
    )

    # Save the best model
    if val_auc > best_auc:
        best_auc = val_auc
        best_model_state = concat_model.state_dict()
        print(f"  → New best validation AUC: {best_auc:.4f}. Saving model state.")

# load the best model state after training
if best_model_state is not None:
    concat_model.load_state_dict(best_model_state)
    print("Loaded best model state for Concatenation Model.")
# Out:
# --- Training Concatenation Model ---
# Training: 100%|██████████| 67/67 [00:45<00:00,  1.47it/s]
# Validating: 100%|██████████| 17/17 [00:11<00:00,  1.44it/s]
# Epoch 1/10 — Train Loss: 0.4356 | Val AUC: 0.9100 | Acc: 0.8389 | Prec: 0.8571 | Rec: 0.7938 | F1: 0.8242
#   → New best validation AUC: 0.9100. Saving model state.
# Training: 100%|██████████| 67/67 [00:41<00:00,  1.61it/s]
# Validating: 100%|██████████| 17/17 [00:11<00:00,  1.48it/s]
# Epoch 2/10 — Train Loss: 0.3774 | Val AUC: 0.9123 | Acc: 0.8444 | Prec: 0.8560 | Rec: 0.8093 | F1: 0.8320
#   → New best validation AUC: 0.9123. Saving model state.
# Training: 100%|██████████| 67/67 [00:42<00:00,  1.59it/s]
# Validating: 100%|██████████| 17/17 [00:15<00:00,  1.12it/s]
# Epoch 3/10 — Train Loss: 0.3879 | Val AUC: 0.9166 | Acc: 0.8537 | Prec: 0.8397 | Rec: 0.8560 | F1: 0.8478
#   → New best validation AUC: 0.9166. Saving model state.
# Training: 100%|██████████| 67/67 [00:50<00:00,  1.33it/s]
# Validating: 100%|██████████| 17/17 [00:11<00:00,  1.48it/s]
# Epoch 4/10 — Train Loss: 0.3661 | Val AUC: 0.9183 | Acc: 0.8537 | Prec: 0.8678 | Rec: 0.8171 | F1: 0.8417
#   → New best validation AUC: 0.9183. Saving model state.
# Training: 100%|██████████| 67/67 [00:52<00:00,  1.27it/s]
# Validating: 100%|██████████| 17/17 [00:14<00:00,  1.14it/s]
# Epoch 5/10 — Train Loss: 0.3420 | Val AUC: 0.9138 | Acc: 0.8463 | Prec: 0.8783 | Rec: 0.7860 | F1: 0.8296
# Training: 100%|██████████| 67/67 [00:46<00:00,  1.43it/s]
# Validating: 100%|██████████| 17/17 [00:10<00:00,  1.57it/s]
# Epoch 6/10 — Train Loss: 0.3367 | Val AUC: 0.9066 | Acc: 0.8519 | Prec: 0.8340 | Rec: 0.8599 | F1: 0.8467
# Training: 100%|██████████| 67/67 [00:46<00:00,  1.43it/s]
# Validating: 100%|██████████| 17/17 [00:16<00:00,  1.00it/s]
# Epoch 7/10 — Train Loss: 0.3233 | Val AUC: 0.9151 | Acc: 0.8556 | Prec: 0.8623 | Rec: 0.8288 | F1: 0.8452
# Training: 100%|██████████| 67/67 [00:49<00:00,  1.35it/s]
# Validating: 100%|██████████| 17/17 [00:13<00:00,  1.22it/s]
# Epoch 8/10 — Train Loss: 0.3114 | Val AUC: 0.9190 | Acc: 0.8593 | Prec: 0.8884 | Rec: 0.8054 | F1: 0.8449
#   → New best validation AUC: 0.9190. Saving model state.
# Training: 100%|██████████| 67/67 [00:42<00:00,  1.59it/s]
# Validating: 100%|██████████| 17/17 [00:09<00:00,  1.80it/s]
# Epoch 9/10 — Train Loss: 0.2927 | Val AUC: 0.9174 | Acc: 0.8463 | Prec: 0.8271 | Rec: 0.8560 | F1: 0.8413
# Training: 100%|██████████| 67/67 [00:41<00:00,  1.63it/s]
# Validating: 100%|██████████| 17/17 [00:10<00:00,  1.55it/s]
# Epoch 10/10 — Train Loss: 0.2714 | Val AUC: 0.9153 | Acc: 0.8426 | Prec: 0.8094 | Rec: 0.8755 | F1: 0.8411
# Loaded best model state for Concatenation Model.

# %%
torch.save(best_model_state, 'concat_model_best_auc.pth')
print("Best Concatenation Model state saved.")
# Out:
# Best Concatenation Model state saved.

# %% [markdown]
# #### Train the Attention Fusion Model

# %%
# Load the saved model
attention_model = AttentionFusionModel(
    num_img_features=num_img_features,
    num_tabular_features=len(tabular_vector)
).to(device)

attention_model.load_state_dict(torch.load('attention_model_best_auc.pth', map_location=device))
attention_model.eval() # Set the model to evaluation mode
print("Concatenation Model loaded successfully.")
# Out:
# Concatenation Model loaded successfully.

# %%
print("\n--- Training Attention Fusion Model ---")
attention_model = attention_model = AttentionFusionModel(
    num_img_features=num_img_features,
    num_tabular_features=len(tabular_vector)
).to(device)

optimizer_attn = torch.optim.Adam(attention_model.parameters(), lr=1e-4) # COMPLETE
criterion = torch.nn.BCEWithLogitsLoss() # COMPLETE

attention_aucs = []
attention_accuracies = []
attention_precisions = []
attention_recalls = []
attention_f1s = []

best_auc = 0.0
best_model_state = None

for epoch in range(num_epochs):
    # --- train ---
    train_loss = train_one_epoch(
        attention_model, train_loader, optimizer_attn, criterion, device # COMPLETE
    )

    all_labels, all_probs = validate(attention_model, val_loader, device) # COMPLETE)

    # convert to numpy arrays
    all_labels = np.array(all_labels)
    all_probs  = np.array(all_probs)

    # compute AUC
    val_auc = roc_auc_score(all_labels, all_probs)

    # threshold into predictions
    val_preds = (all_probs >= 0.5).astype(int)

    # compute other metrics
    val_acc   = accuracy_score(all_labels, val_preds) # COMPLETE
    val_prec  = precision_score(all_labels, val_preds, zero_division=0) # COMPLETE
    val_rec   = recall_score(all_labels, val_preds, zero_division=0) # COMPLETE
    val_f1    = f1_score(all_labels, val_preds, zero_division=0)# COMPLETE

    # store for later plotting
    attention_aucs.append(val_auc)
    attention_accuracies.append(val_acc)
    attention_precisions.append(val_prec)
    attention_recalls.append(val_rec)
    attention_f1s.append(val_f1)

    # log it
    print(
        f"Epoch {epoch+1}/{num_epochs} — "
        f"Train Loss: {train_loss:.4f} | "
        f"Val AUC: {val_auc:.4f} | "
        f"Acc: {val_acc:.4f} | "
        f"Prec: {val_prec:.4f} | "
        f"Rec: {val_rec:.4f} | "
        f"F1: {val_f1:.4f}"
    )

    # save best
    if val_auc > best_auc:
        best_auc = val_auc
        best_model_state = attention_model.state_dict()
        print(f"  → New best validation AUC: {best_auc:.4f}. Saving model state.")

# load the best model
if best_model_state is not None:
    attention_model.load_state_dict(best_model_state)
    print("Loaded best model state for Attention Fusion Model.")
# Out:
# --- Training Attention Fusion Model ---
# Training: 100%|██████████| 67/67 [00:52<00:00,  1.28it/s]
# Validating: 100%|██████████| 17/17 [00:09<00:00,  1.77it/s]
# Epoch 1/10 — Train Loss: 0.4572 | Val AUC: 0.9096 | Acc: 0.8389 | Prec: 0.8602 | Rec: 0.7899 | F1: 0.8235
#   → New best validation AUC: 0.9096. Saving model state.
# Training: 100%|██████████| 67/67 [00:51<00:00,  1.31it/s]
# Validating: 100%|██████████| 17/17 [00:12<00:00,  1.40it/s]
# Epoch 2/10 — Train Loss: 0.3773 | Val AUC: 0.9122 | Acc: 0.8352 | Prec: 0.8415 | Rec: 0.8054 | F1: 0.8231
#   → New best validation AUC: 0.9122. Saving model state.
# Training: 100%|██████████| 67/67 [00:41<00:00,  1.60it/s]
# Validating: 100%|██████████| 17/17 [00:11<00:00,  1.43it/s]
# Epoch 3/10 — Train Loss: 0.3797 | Val AUC: 0.9150 | Acc: 0.8556 | Prec: 0.8594 | Rec: 0.8327 | F1: 0.8458
#   → New best validation AUC: 0.9150. Saving model state.
# Training: 100%|██████████| 67/67 [00:47<00:00,  1.40it/s]
# Validating: 100%|██████████| 17/17 [00:11<00:00,  1.54it/s]
# Epoch 4/10 — Train Loss: 0.3682 | Val AUC: 0.9191 | Acc: 0.8389 | Prec: 0.8632 | Rec: 0.7860 | F1: 0.8228
#   → New best validation AUC: 0.9191. Saving model state.
# Training: 100%|██████████| 67/67 [00:41<00:00,  1.63it/s]
# Validating: 100%|██████████| 17/17 [00:10<00:00,  1.61it/s]
# Epoch 5/10 — Train Loss: 0.3538 | Val AUC: 0.9175 | Acc: 0.8519 | Prec: 0.8498 | Rec: 0.8366 | F1: 0.8431
# Training: 100%|██████████| 67/67 [00:44<00:00,  1.50it/s]
# Validating: 100%|██████████| 17/17 [00:16<00:00,  1.02it/s]
# Epoch 6/10 — Train Loss: 0.3307 | Val AUC: 0.9184 | Acc: 0.8426 | Prec: 0.8233 | Rec: 0.8521 | F1: 0.8375
# Training: 100%|██████████| 67/67 [00:40<00:00,  1.65it/s]
# Validating: 100%|██████████| 17/17 [00:10<00:00,  1.63it/s]
# Epoch 7/10 — Train Loss: 0.3259 | Val AUC: 0.9202 | Acc: 0.8537 | Prec: 0.8560 | Rec: 0.8327 | F1: 0.8442
#   → New best validation AUC: 0.9202. Saving model state.
# Training: 100%|██████████| 67/67 [00:41<00:00,  1.61it/s]
# Validating: 100%|██████████| 17/17 [00:10<00:00,  1.55it/s]
# Epoch 8/10 — Train Loss: 0.3127 | Val AUC: 0.9176 | Acc: 0.8519 | Prec: 0.8798 | Rec: 0.7977 | F1: 0.8367
# Training: 100%|██████████| 67/67 [00:42<00:00,  1.58it/s]
# Validating: 100%|██████████| 17/17 [00:10<00:00,  1.66it/s]
# Epoch 9/10 — Train Loss: 0.3081 | Val AUC: 0.9191 | Acc: 0.8519 | Prec: 0.8734 | Rec: 0.8054 | F1: 0.8381
# Training: 100%|██████████| 67/67 [00:40<00:00,  1.64it/s]
# Validating: 100%|██████████| 17/17 [00:10<00:00,  1.64it/s]
# Epoch 10/10 — Train Loss: 0.2969 | Val AUC: 0.9204 | Acc: 0.8611 | Prec: 0.8611 | Rec: 0.8444 | F1: 0.8527
#   → New best validation AUC: 0.9204. Saving model state.
# Loaded best model state for Attention Fusion Model.

# %%
torch.save(best_model_state, 'attention_model_best_auc.pth')
print("Best Concatenation Model state saved.")
# Out:
# Best Concatenation Model state saved.

# %% [markdown]
# #### Train the Bilinear Fusion Model

# %%
# Load the saved model
bilinear_model = BilinearFusionModel(
    num_img_features=num_img_features,
    num_tabular_features=len(tabular_vector)
).to(device)

bilinear_model.load_state_dict(torch.load('bilinear_model_best_auc.pth', map_location=device))
bilinear_model.eval() # Set the model to evaluation mode
print("Concatenation Model loaded successfully.")
# Out:
# Concatenation Model loaded successfully.

# %%
print("\n--- Training Bilinear Fusion Model ---")
bilinear_model = bilinear_model = BilinearFusionModel(
    num_img_features=num_img_features,
    num_tabular_features=len(tabular_vector)
).to(device)

optimizer_attn = torch.optim.Adam(bilinear_model.parameters(), lr=1e-4)# COMPLETE
criterion = # COMPLETE

bilinear_aucs = []
bilinear_accuracies = []
bilinear_precisions = []
bilinear_recalls = []
bilinear_f1s = []

best_auc = 0.0
best_model_state = None

for epoch in range(num_epochs):
    # --- train ---
    train_loss = train_one_epoch(
        bilinear_model, train_loader, optimizer_bilinear, criterion, device # COMPLETE
    )

    all_labels, all_probs = validate(bilinear_model, val_loader, device) # COMPLETE)

    # convert to numpy arrays
    all_labels = np.array(all_labels)
    all_probs  = np.array(all_probs)

    # compute AUC
    val_auc = roc_auc_score(all_labels, all_probs) # COMPLETE)

    # threshold into predictions
    val_preds = (all_probs >= 0.5).astype(int)

    # compute other metrics
    val_acc   = accuracy_score(all_labels, val_preds)
    val_prec  = precision_score(all_labels, val_preds, zero_division=0)
    val_rec   = recall_score(all_labels, val_preds, zero_division=0)
    val_f1    = f1_score(all_labels, val_preds, zero_division=0)

    # store for later plotting
    bilinear_aucs.append(val_auc)
    bilinear_accuracies.append(val_acc)
    bilinear_precisions.append(val_prec)
    bilinear_recalls.append(val_rec)
    bilinear_f1s.append(val_f1)

    # log it
    print(
        f"Epoch {epoch+1}/{num_epochs} — "
        f"Train Loss: {train_loss:.4f} | "
        f"Val AUC: {val_auc:.4f} | "
        f"Acc: {val_acc:.4f} | "
        f"Prec: {val_prec:.4f} | "
        f"Rec: {val_rec:.4f} | "
        f"F1: {val_f1:.4f}"
    )

    # save best
    if val_auc > best_auc:
        best_auc = val_auc
        best_model_state = bilinear_model.state_dict()
        print(f"  → New best validation AUC: {best_auc:.4f}. Saving model state.")

# load the best model
if best_model_state is not None:
    bilinear_model.load_state_dict(best_model_state)
    print("Loaded best model state for Bilinear Fusion Model.")
# Out:
#   File "/tmp/ipython-input-1261/379654398.py", line 8
#     criterion = # COMPLETE
#                 ^
# SyntaxError: invalid syntax

# %%
torch.save(best_model_state, 'bilinear_model_best_auc.pth')
print("Best Concatenation Model state saved.")

# %% [markdown]
# ### Comparison and Discussion
#
#
#
# #### Compare Validation AUC
#
# Finally, let's plot the validation AUC curves for both models to visually compare their performance over the training epochs.

# %%
# Download and load metrics if necessary
# !curl https://uni-bonn.sciebo.de/s/we97TCYMLcFZ4ia/download/model_metrics.npz --output model_metrics.npz

# Load the metric arrays from the .npz file
metrics_data = np.load('model_metrics.npz')

concat_aucs = metrics_data['concat_aucs'].tolist()
concat_accuracies = metrics_data['concat_accuracies'].tolist()
concat_precisions = metrics_data['concat_precisions'].tolist()
concat_recalls = metrics_data['concat_recalls'].tolist()
concat_f1s = metrics_data['concat_f1s'].tolist()

attention_aucs = metrics_data['attention_aucs'].tolist()
attention_accuracies = metrics_data['attention_accuracies'].tolist()
attention_precisions = metrics_data['attention_precisions'].tolist()
attention_recalls = metrics_data['attention_recalls'].tolist()
attention_f1s = metrics_data['attention_f1s'].tolist()

bilinear_aucs = metrics_data['bilinear_aucs'].tolist()
bilinear_accuracies = metrics_data['bilinear_accuracies'].tolist()
bilinear_precisions = metrics_data['bilinear_precisions'].tolist()
bilinear_recalls = metrics_data['bilinear_recalls'].tolist()
bilinear_f1s = metrics_data['bilinear_f1s'].tolist()

print("Model metrics loaded successfully.")

# %%
# pack your metric histories into a dict
metrics = {
    'AUC':        (concat_aucs,        attention_aucs,        bilinear_aucs),
    'Accuracy':   (concat_accuracies,  attention_accuracies,  bilinear_accuracies),
    'Precision':  (concat_precisions,  attention_precisions,  bilinear_precisions),
    'Recall':     (concat_recalls,     attention_recalls,     bilinear_recalls),
    'F1 Score':   (concat_f1s,         attention_f1s,         bilinear_f1s),
}

epochs = range(1, num_epochs + 1)

model_data = {
    'Concatenation Model': (concat_aucs, concat_accuracies, concat_precisions, concat_recalls, concat_f1s, 'o', '-'),
    'Attention Fusion Model': (attention_aucs, attention_accuracies, attention_precisions, attention_recalls, attention_f1s, 's', '--'),
    'Bilinear Fusion Model': (bilinear_aucs, bilinear_accuracies, bilinear_precisions, bilinear_recalls, bilinear_f1s, '*', '-.'),
}


for metric_name in metrics.keys():
    plt.figure(figsize=(10, 6))
    for model_name, data in model_data.items():
        metric_vals = data[list(metrics.keys()).index(metric_name)]
        marker = data[-2]
        linestyle = data[-1]

        # Only plot if the metric list is not empty
        if metric_vals:
            plt.plot(epochs[:len(metric_vals)], metric_vals, marker=marker, linestyle=linestyle, label=model_name)

    plt.title(f'Validation {metric_name} Comparison of Fusion Models')
    plt.xlabel('Epoch')
    plt.ylabel(f'Validation {metric_name}')
    plt.xticks(epochs)
    plt.grid(True)
    plt.legend()
    plt.show()


# Print final epoch values for quick reference
print("Final Validation Metrics:")
for metric_name, (concat_vals, attn_vals, bilinear_vals) in metrics.items():
    concat_last = f"{concat_vals[-1]:.4f}" if concat_vals else 'N/A'
    attn_last = f"{attn_vals[-1]:.4f}" if attn_vals else 'N/A'
    bilinear_last = f"{bilinear_vals[-1]:.4f}" if bilinear_vals else 'N/A'
    print(f"  {metric_name}: "
          f"Concat = {concat_last}, "
          f"Attention = {attn_last}, "
          f"Bilinear = {bilinear_last}")

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score, RocCurveDisplay
from torchvision.models import densenet121

# Load pre-trained DenseNet-121
model_densenet = densenet121() # COMPLETE
model_densenet.classifier = nn.Linear(model_densenet.classifier.in_features, 1)
model_densenet.load_state_dict(torch.load('./densenet121-classification.pth', map_location=device))

model_list  = [model_densenet, concat_model, attention_model, bilinear_model] # COMPLETE]

all_preds_proba = {}
all_labels      = None
model_names = ['Baseline DenseNet-121 (Image Only)', 'Concatenation Fusion Model', 'Attention Fusion Model', 'Bilinear Fusion Model']

# Main Evaluation Loop
for model, name in zip(model_list, model_names):
    model.eval()
    model.to(device)

    probs_list, labels_list = [], []

    with torch.no_grad():
        # The loader yields three items: images, tabular data, and labels
        for images, tabular, labels in tqdm(test_loader, desc=f"Evaluating {name}"):
            images, tabular = images.to(device), tabular.to(device)

            # Handle different model input signatures
            if "Image Only" in name:
                # The baseline model only takes the image
                out = model(images)
            else:
                # The fusion models take both the image and tabular data
                out = model(images, tabular)

            probs = torch.sigmoid(out).squeeze()

            probs_list.extend(probs.cpu().numpy())
            labels_list.extend(labels.numpy())

    preds_proba = np.array(probs_list)
    labels      = np.array(labels_list)

    all_preds_proba[name] = preds_proba
    if all_labels is None:
        all_labels = labels

    preds_binary = (preds_proba > 0.5).astype(int)

    # Calculate and Print Metrics
    acc     = accuracy_score(labels, preds_binary)
    prec    = precision_score(labels, preds_binary, zero_division=0)
    rec     = recall_score(labels, preds_binary, zero_division=0)
    f1      = f1_score(labels, preds_binary, zero_division=0)
    roc_auc = roc_auc_score(labels, preds_proba)

    print(f"\n--- Model: {name} ---")
    print(f"  Accuracy : {acc:.4f}")
    print(f"  Precision: {prec:.4f}")
    print(f"  Recall   : {rec:.4f}")
    print(f"  F1-score : {f1:.4f}")
    print(f"  ROC AUC  : {roc_auc:.4f}")
    print("-" * 45)


# Plot the Combined ROC Curves
plt.figure(figsize=(10, 8))
ax = plt.gca()

for name, preds_proba in all_preds_proba.items():
    auc = roc_auc_score(all_labels, preds_proba)
    RocCurveDisplay.from_predictions(
        all_labels,
        preds_proba,
        name=f'{name} (AUC = {auc:.4f})',
        ax=ax
    )

ax.plot([0, 1], [0, 1], 'k--', label='Chance Level (AUC = 0.5)')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve Comparison on Test Set')
plt.legend(frameon=False)
plt.show()
# Out:
# Evaluating Baseline DenseNet-121 (Image Only): 100%|██████████| 17/17 [00:09<00:00,  1.73it/s]
# --- Model: Baseline DenseNet-121 (Image Only) ---
#   Accuracy : 0.8222
#   Precision: 0.8207
#   Recall   : 0.8016
#   F1-score : 0.8110
#   ROC AUC  : 0.9011
# ---------------------------------------------
# Evaluating Concatenation Fusion Model: 100%|██████████| 17/17 [00:10<00:00,  1.55it/s]
# --- Model: Concatenation Fusion Model ---
#   Accuracy : 0.8426
#   Precision: 0.8094
#   Recall   : 0.8755
#   F1-score : 0.8411
#   ROC AUC  : 0.9153
# ---------------------------------------------
# Evaluating Attention Fusion Model: 100%|██████████| 17/17 [00:11<00:00,  1.54it/s]
# --- Model: Attention Fusion Model ---
#   Accuracy : 0.8611
#   Precision: 0.8611
#   Recall   : 0.8444
#   F1-score : 0.8527
#   ROC AUC  : 0.9204
# ---------------------------------------------
# Evaluating Bilinear Fusion Model: 100%|██████████| 17/17 [00:09<00:00,  1.77it/s]
# --- Model: Bilinear Fusion Model ---
#   Accuracy : 0.8611
#   Precision: 0.8473
#   Recall   : 0.8638
#   F1-score : 0.8555
#   ROC AUC  : 0.9347
# ---------------------------------------------

# %% [markdown]
# Our results show that both multi-modal fusion strategies were effective. Which model was better?
#
# Which strategy performed best and why?
#
# Out of all the methods tested, the Bilinear model performed the best. It had the highest overall score (an AUC of 93.4%) and the best balance of making correct predictions without false alarms (F1-score of 0.8555). Instead of just concatenating the image and tabular features together side-by-side, bilinear fusion computes complex, multiplicative interactions between the two data types. This allowed the network to learn much deeper, more nuanced relationships between the patient's demographics and their medical scans as the model could actively learn how a specific age or sex changed the context of the visual patterns it saw in the image.
